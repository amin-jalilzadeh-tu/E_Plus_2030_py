# %%
"""
main.py

Orchestrates the entire workflow:
  1) Loads main_config.json (which has two sets of override flags: excel_overrides, user_config_overrides).
  2) Loads the default dictionaries for fenestration, DHW, HVAC, etc.
  3) Applies Excel-based overrides if the corresponding "override_*_excel" flags are True.
  4) Applies user JSON overrides if "override_*_json" flags are True, 
     loading each separate JSON file (fenestration.json, dhw.json, etc.) as needed.
  5) Creates IDFs, runs simulations, merges results, etc. according to the config.
"""

import os
import json
import logging
import pandas as pd

# --------------------------------------------------------------------------
# A) Overriding modules (Excel + JSON partial overrides)
# --------------------------------------------------------------------------
from excel_overrides import (
    override_dhw_lookup_from_excel_file,
    override_epw_lookup_from_excel_file,
    override_lighting_lookup_from_excel_file,
    override_hvac_lookup_from_excel_file,
    override_vent_lookup_from_excel_file
)
# For fenestration, we use a new approach that merges default data, Excel, JSON in one place:
from idf_objects.fenez.fenez_config_manager import build_fenez_config

# If you have geometry or shading Excel overrides, import them as well.

# --------------------------------------------------------------------------
# B) IDF creation & scenario modules
# --------------------------------------------------------------------------
from idf_creation import create_idfs_for_all_buildings
from main_modifi import run_modification_workflow

# --------------------------------------------------------------------------
# C) Validation
# --------------------------------------------------------------------------
from validation.main_validation import run_validation_process

# --------------------------------------------------------------------------
# D) Calibration, Sensitivity, Surrogate modules
# --------------------------------------------------------------------------
from cal.unified_calibration import (
    load_scenario_params as cal_load_scenario_params,
    build_param_specs_from_scenario,
    simulate_or_surrogate,
    CalibrationManager,
    save_history_to_csv
)
from cal.unified_sensitivity import run_sensitivity_analysis
from cal.unified_surrogate import (
    load_scenario_params as sur_load_scenario_params,
    pivot_scenario_params,
    filter_top_parameters,
    load_sim_results,
    aggregate_results,
    merge_params_with_results,
    build_and_save_surrogate
)

###############################################################################
# 1) Logging Setup
###############################################################################
def setup_logging(log_level=logging.INFO):
    logging.basicConfig(
        level=log_level,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return logging.getLogger(__name__)


###############################################################################
# 2) Utility: load JSON from file
###############################################################################
def load_json(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"JSON file not found: {filepath}")
    with open(filepath, "r") as f:
        return json.load(f)


###############################################################################
# 3) Main Orchestration
###############################################################################
def main():
    logger = setup_logging()
    logger.info("=== Starting main.py ===")

    # --------------------------------------------------------------------------
    # A) Load main_config.json
    # --------------------------------------------------------------------------
    user_configs_folder = r"D:\Documents\E_Plus_2030_py\user_configs"
    main_config_path = os.path.join(user_configs_folder, "main_config.json")

    if not os.path.isfile(main_config_path):
        logger.error(f"[ERROR] Cannot find main_config.json at {main_config_path}")
        return

    main_config = load_json(main_config_path)
    
    # Extract relevant sections
    paths_dict    = main_config.get("paths", {})
    excel_flags   = main_config.get("excel_overrides", {})
    user_flags    = main_config.get("user_config_overrides", {})
    def_dicts     = main_config.get("default_dicts", {})
    idf_cfg       = main_config.get("idf_creation", {})
    modification_cfg = main_config.get("modification", {})
    validation_cfg   = main_config.get("validation", {})
    sens_cfg         = main_config.get("sensitivity", {})
    sur_cfg          = main_config.get("surrogate", {})
    cal_cfg          = main_config.get("calibration", {})

    # --------------------------------------------------------------------------
    # B) Setup default dictionaries for each module
    # --------------------------------------------------------------------------
    # Fenestration
    base_res_data    = def_dicts.get("res_data", {})
    base_nonres_data = def_dicts.get("nonres_data", {})
    # Others
    dhw_lookup       = def_dicts.get("dhw", {})
    epw_lookup       = def_dicts.get("epw", [])
    lighting_lookup  = def_dicts.get("lighting", {})
    hvac_lookup      = def_dicts.get("hvac", {})
    vent_lookup      = def_dicts.get("vent", {})

    # --------------------------------------------------------------------------
    # C) Apply Excel-based overrides if flagged
    # --------------------------------------------------------------------------
    # 1) Fenestration via build_fenez_config => do_excel_override
    override_fenez_excel = excel_flags.get("override_fenez_excel", False)
    fenez_excel_path      = paths_dict.get("fenez_excel", "")

    # We'll *initially* call build_fenez_config with do_excel_override=override_fenez_excel
    # We won't pass user_fenez_overrides yet, or we'll pass an empty list. We'll do that below or unify it.
    # But a simpler approach is to also handle user_fenez_overrides here, see next step (D).
    # For now, let's do partial:
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=base_res_data,
        base_nonres_data=base_nonres_data,
        excel_path=fenez_excel_path,
        do_excel_override=override_fenez_excel,
        user_fenez_overrides=[]  # we might fill this in after loading fenestration.json below
    )

    # 2) DHW Excel
    if excel_flags.get("override_dhw_excel", False):
        dhw_lookup = override_dhw_lookup_from_excel_file(
            dhw_excel_path=paths_dict.get("dhw_excel", ""),
            default_dhw_lookup=dhw_lookup,
            override_dhw_flag=True
        )

    # 3) EPW Excel
    if excel_flags.get("override_epw_excel", False):
        epw_lookup = override_epw_lookup_from_excel_file(
            epw_excel_path=paths_dict.get("epw_excel", ""),
            epw_lookup=epw_lookup,
            override_epw_flag=True
        )

    # 4) Lighting Excel
    if excel_flags.get("override_lighting_excel", False):
        lighting_lookup = override_lighting_lookup_from_excel_file(
            lighting_excel_path=paths_dict.get("lighting_excel", ""),
            lighting_lookup=lighting_lookup,
            override_lighting_flag=True
        )

    # 5) HVAC Excel
    if excel_flags.get("override_hvac_excel", False):
        hvac_lookup = override_hvac_lookup_from_excel_file(
            hvac_excel_path=paths_dict.get("hvac_excel", ""),
            hvac_lookup=hvac_lookup,
            override_hvac_flag=True
        )

    # 6) Vent Excel
    if excel_flags.get("override_vent_excel", False):
        vent_lookup = override_vent_lookup_from_excel_file(
            vent_excel_path=paths_dict.get("vent_excel", ""),
            vent_lookup=vent_lookup,
            override_vent_flag=True
        )

    # --------------------------------------------------------------------------
    # D) Apply User JSON overrides if flagged
    #    For each module, if override_*_json = True, we load the separate file 
    #    (e.g. fenestration.json, dhw.json, etc.) and apply partial overrides.
    # --------------------------------------------------------------------------
    # 1) Fenestration user JSON
    override_fenez_json = user_flags.get("override_fenez_json", False)
    if override_fenez_json:
        fenestration_json_path = os.path.join(user_configs_folder, "fenestration.json")
        if os.path.isfile(fenestration_json_path):
            try:
                fenestration_data = load_json(fenestration_json_path)
            except Exception as e:
                fenestration_data = {}
                logger.error(f"Error loading fenestration.json: {e}")

            # Typically "fenestration_data" might be: { "fenestration": [ { ... }, {...} ] }
            user_fenez_overrides = fenestration_data.get("fenestration", [])
        else:
            logger.warning(f"[WARN] fenestration.json not found at {fenestration_json_path}. No user fenestration overrides.")
            user_fenez_overrides = []
    else:
        user_fenez_overrides = []

    # Now we re-run build_fenez_config so that it merges user_fenez_overrides 
    # with the already Excel-overridden dictionaries (updated_res_data, updated_nonres_data).
    # If you prefer to do it in one step, you can incorporate it directly in build_fenez_config. 
    # But here's a 2-step example:
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=updated_res_data,
        base_nonres_data=updated_nonres_data,
        excel_path="",             # no need to re-apply Excel
        do_excel_override=False,   # we already did that
        user_fenez_overrides=user_fenez_overrides
    )


    # 2) DHW user JSON
    override_dhw_json = user_flags.get("override_dhw_json", False)
    user_config_dhw = None  # We will store a list of overrides here
    if override_dhw_json:
        dhw_json_path = os.path.join(user_configs_folder, "dhw.json")
        if os.path.isfile(dhw_json_path):
            try:
                dhw_data = load_json(dhw_json_path)
                user_config_dhw = dhw_data.get("dhw", [])
            except Exception as e:
                logger.error(f"[ERROR] loading dhw.json => {e}")
                user_config_dhw = None
        else:
            logger.warning(f"[WARN] dhw.json not found at {dhw_json_path}")
            user_config_dhw = None
    else:
        user_config_dhw = None

    # 3) EPW user JSON
    override_epw_json = user_flags.get("override_epw_json", False)
    user_config_epw = []
    if override_epw_json:
        epw_json_path = os.path.join(user_configs_folder, "epw.json")
        if os.path.isfile(epw_json_path):
            epw_data = load_json(epw_json_path)
            user_config_epw = epw_data.get("epw", [])


    # 4) Lighting user JSON
    override_lighting_json = user_flags.get("override_lighting_json", False)
    user_config_lighting = None
    if override_lighting_json:
        lighting_json_path = os.path.join(user_configs_folder, "lighting.json")
        if os.path.isfile(lighting_json_path):
            try:
                lighting_data = load_json(lighting_json_path)
                user_config_lighting = lighting_data.get("lighting", [])
            except Exception as e:
                logger.error(f"[ERROR] loading lighting.json => {e}")
                user_config_lighting = None


    # 5) HVAC user JSON
    override_hvac_json = user_flags.get("override_hvac_json", False)
    if override_hvac_json:
        hvac_json_path = os.path.join(user_configs_folder, "hvac.json")
        hvac_data = load_json(hvac_json_path)
        user_config_hvac = hvac_data.get("hvac", [])
    else:
        user_config_hvac = None

    # 6) Vent user JSON
    override_vent_json = user_flags.get("override_vent_json", False)
    if override_vent_json:
        pass  # similarly handle vent.json

    # 7) Geometry user JSON
    override_geometry_json = user_flags.get("override_geometry_json", False)
    geometry_dict = {}
    if override_geometry_json:
        geometry_json_path = os.path.join(user_configs_folder, "geometry.json")
        if os.path.isfile(geometry_json_path):
            # load geometry config
            try:
                geom_data = load_json(geometry_json_path)
                from user_config_overrides import apply_geometry_user_config
                # e.g. if geom_data = { "geometry": [ {...} ] }
                geometry_dict = apply_geometry_user_config({}, geom_data.get("geometry", []))
            except Exception as e:
                logger.error(f"[ERROR] loading geometry.json => {e}")
        else:
            logger.warning(f"[WARN] geometry.json not found.")

    # 8) Shading user JSON
    override_shading_json = user_flags.get("override_shading_json", False)
    shading_dict = {}
    if override_shading_json:
        shading_json_path = os.path.join(user_configs_folder, "shading.json")
        if os.path.isfile(shading_json_path):
            # load shading config
            try:
                shading_data = load_json(shading_json_path)
                from user_config_overrides import apply_shading_user_config
                shading_dict = apply_shading_user_config({}, shading_data.get("shading", []))
            except Exception as e:
                logger.error(f"[ERROR] loading shading.json => {e}")
        else:
            logger.warning("[WARN] shading.json not found.")


    if override_vent_json:
        vent_json_path = os.path.join(user_configs_folder, "vent.json")
        if os.path.isfile(vent_json_path):
            vent_data = load_json(vent_json_path)
            user_config_vent = vent_data.get("vent", [])
        else:
            user_config_vent = []
    else:
        user_config_vent = []

    # --------------------------------------------------------------------------
    # E) IDF Creation (if enabled)
    # --------------------------------------------------------------------------
    if idf_cfg.get("perform_idf_creation", False):
        logger.info("[INFO] IDF creation is ENABLED.")

        # Load building data
        bldg_data_path = paths_dict.get("building_data", "")
        if os.path.isfile(bldg_data_path):
            df_buildings = pd.read_csv(bldg_data_path)
        else:
            logger.warning(f"[WARN] Building data CSV not found at {bldg_data_path}. Using empty DF.")
            df_buildings = pd.DataFrame()

        # Create IDFs
        create_idfs_for_all_buildings(
            df_buildings=df_buildings,
            scenario=idf_cfg.get("scenario", "scenario1"),
            calibration_stage=idf_cfg.get("calibration_stage", "pre_calibration"),
            strategy=idf_cfg.get("strategy", "B"),
            random_seed=idf_cfg.get("random_seed", 42),
            # geometry overrides
            user_config_geom=None if not override_geometry_json else geom_data.get("geometry", []),
            user_config_lighting=user_config_lighting,  # or load from your lighting approach above
            user_config_dhw=user_config_dhw,       # or dhw_data if needed
            # Instead of user_config_fenez, we pass the final fenestration dicts:
            res_data=updated_res_data,
            nonres_data=updated_nonres_data,
            user_config_hvac=user_config_hvac,      # or hvac_data if needed
            user_config_vent=user_config_vent,      # or vent_data if needed
            user_config_epw=user_config_epw,   # <--- Add this line

            run_simulations=idf_cfg.get("run_simulations", True),
            simulate_config={"num_workers": idf_cfg.get("num_workers", 4)},
            post_process=idf_cfg.get("post_process", True)
        )
    else:
        logger.info("[INFO] Skipping IDF creation per user config.")

    # --------------------------------------------------------------------------
    # F) Scenario Modification / Generation
    # --------------------------------------------------------------------------
    if modification_cfg.get("perform_modification", False):
        logger.info("[INFO] Scenario modification is ENABLED.")
        run_modification_workflow(modification_cfg["modify_config"])
    else:
        logger.info("[INFO] Skipping scenario modification.")

    # --------------------------------------------------------------------------
    # G) Global Validation
    # --------------------------------------------------------------------------
    if validation_cfg.get("perform_validation", False):
        logger.info("[INFO] Global Validation is ENABLED.")
        run_validation_process(validation_cfg["config"])
    else:
        logger.info("[INFO] Skipping global validation.")

    # --------------------------------------------------------------------------
    # H) Sensitivity Analysis
    # --------------------------------------------------------------------------
    if sens_cfg.get("perform_sensitivity", False):
        logger.info("[INFO] Sensitivity Analysis is ENABLED.")
        run_sensitivity_analysis(
            scenario_folder=sens_cfg["scenario_folder"],
            method=sens_cfg["method"],
            results_csv=sens_cfg.get("results_csv", ""),
            target_variable=sens_cfg.get("target_variable", ""),
            output_csv=sens_cfg.get("output_csv", "sensitivity_output.csv"),
            n_morris_trajectories=sens_cfg.get("n_morris_trajectories", 10),
            num_levels=sens_cfg.get("num_levels", 4),
            n_sobol_samples=sens_cfg.get("n_sobol_samples", 128)
        )
    else:
        logger.info("[INFO] Skipping sensitivity analysis.")

    # --------------------------------------------------------------------------
    # I) Surrogate Modeling
    # --------------------------------------------------------------------------
    if sur_cfg.get("perform_surrogate", False):
        logger.info("[INFO] Surrogate Modeling is ENABLED.")

        scenario_folder = sur_cfg["scenario_folder"]
        results_csv     = sur_cfg["results_csv"]
        target_var      = sur_cfg["target_variable"]
        model_out       = sur_cfg["model_out"]
        cols_out        = sur_cfg["cols_out"]
        test_size       = sur_cfg["test_size"]

        # 1) Load & pivot scenario params
        df_scen = sur_load_scenario_params(scenario_folder)
        pivot_df = pivot_scenario_params(df_scen)

        # 2) Optionally filter top parameters
        # pivot_df = filter_top_parameters(pivot_df, "morris_sensitivity.csv", top_n=5)

        # 3) Load & aggregate sim results
        df_sim = load_sim_results(results_csv)
        df_agg = aggregate_results(df_sim)

        # 4) Merge
        merged_df = merge_params_with_results(pivot_df, df_agg, target_var)

        # 5) Build & save surrogate
        rf_model, trained_cols = build_and_save_surrogate(
            df_data=merged_df,
            target_col=target_var,
            model_out_path=model_out,
            columns_out_path=cols_out,
            test_size=test_size,
            random_state=42
        )
        if rf_model:
            logger.info("[INFO] Surrogate model built & saved.")
        else:
            logger.warning("[WARN] Surrogate modeling failed or insufficient data.")
    else:
        logger.info("[INFO] Skipping surrogate modeling.")

    # --------------------------------------------------------------------------
    # J) Calibration
    # --------------------------------------------------------------------------
    if cal_cfg.get("perform_calibration", False):
        logger.info("[INFO] Calibration steps are ENABLED.")

        scenario_folder = cal_cfg["scenario_folder"]
        if not os.path.isdir(scenario_folder):
            logger.error(f"[ERROR] Scenario folder not found: {scenario_folder}")
        else:
            # 1) Load scenario data
            df_scen = cal_load_scenario_params(scenario_folder)
            param_specs = build_param_specs_from_scenario(df_scen)

            # 2) Create manager
            manager = CalibrationManager(param_specs, simulate_or_surrogate)

            # 3) GA approach
            logger.info("[CAL] => GA approach")
            best_params_ga, best_err_ga, hist_ga = manager.run_calibration(
                method="ga",
                pop_size=cal_cfg.get("ga_pop_size", 10),
                generations=cal_cfg.get("ga_generations", 5),
                crossover_prob=cal_cfg.get("ga_crossover_prob", 0.7),
                mutation_prob=cal_cfg.get("ga_mutation_prob", 0.2)
            )
            logger.info(f"[GA] Best error={best_err_ga:.2f}, best params={best_params_ga}")
            save_history_to_csv(hist_ga, "calibration_history_ga.csv")

            # 4) Bayesian approach
            logger.info("[CAL] => Bayesian approach")
            best_params_bayes, best_err_bayes, hist_bayes = manager.run_calibration(
                method="bayes",
                n_calls=cal_cfg.get("bayes_n_calls", 15)
            )
            logger.info(f"[Bayes] Best error={best_err_bayes:.2f}, best params={best_params_bayes}")
            save_history_to_csv(hist_bayes, "calibration_history_bayes.csv")

            # 5) Random approach
            logger.info("[CAL] => Random approach")
            best_params_rand, best_err_rand, hist_rand = manager.run_calibration(
                method="random",
                n_iterations=cal_cfg.get("random_n_iter", 20)
            )
            logger.info(f"[Random] Best error={best_err_rand:.2f}, best params={best_params_rand}")
            save_history_to_csv(hist_rand, "calibration_history_random.csv")

            # 6) Compare final best among GA, Bayes, Random
            results = [
                ("GA", best_params_ga, best_err_ga),
                ("Bayes", best_params_bayes, best_err_bayes),
                ("Random", best_params_rand, best_err_rand)
            ]
            results.sort(key=lambda x: x[2])  # sort by error ascending
            logger.info("\n=== Overall Best Among GA, Bayes, Random ===")
            logger.info(f"Method={results[0][0]}, err={results[0][2]:.2f}, params={results[0][1]}")
    else:
        logger.info("[INFO] Skipping calibration steps.")

    logger.info("=== End of main.py ===")


###############################################################################
# 4) Script Entry
###############################################################################
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 47
#      42 from validation.main_validation import run_validation_process
#      44 # --------------------------------------------------------------------------
#      45 # D) Calibration, Sensitivity, Surrogate modules
#      46 # --------------------------------------------------------------------------
# ---> 47 from cal.unified_calibration import (
#      48     load_scenario_params as cal_load_scenario_params,
#      49     build_param_specs_from_scenario,
#      50     simulate_or_surrogate,
#      51     CalibrationManager,
#      52     save_history_to_csv
#      53 )
#      54 from cal.unified_sensitivity import run_sensitivity_analysis
#      55 from cal.unified_surrogate import (
#      56     load_scenario_params as sur_load_scenario_params,
#      57     pivot_scenario_params,
#    (...)
#      62     build_and_save_surrogate
#      63 )
#
# ImportError: cannot import name 'load_scenario_params' from 'cal.unified_calibration' (d:\Documents\E_Plus_2030_py\cal\unified_calibration.py)

# %%
"""
main.py

Orchestrates the entire workflow:
  1) Loads main_config.json (which has two sets of override flags: excel_overrides, user_config_overrides).
  2) Loads the default dictionaries for fenestration, DHW, HVAC, etc.
  3) Applies Excel-based overrides if the corresponding "override_*_excel" flags are True.
  4) Applies user JSON overrides if "override_*_json" flags are True, 
     loading each separate JSON file (fenestration.json, dhw.json, etc.) as needed.
  5) Creates IDFs, runs simulations, merges results, etc. according to the config.
"""

import os
import json
import logging
import pandas as pd

# --------------------------------------------------------------------------
# A) Overriding modules (Excel + JSON partial overrides)
# --------------------------------------------------------------------------
from excel_overrides import (
    override_dhw_lookup_from_excel_file,
    override_epw_lookup_from_excel_file,
    override_lighting_lookup_from_excel_file,
    override_hvac_lookup_from_excel_file,
    override_vent_lookup_from_excel_file
)
# For fenestration, we use a new approach that merges default data, Excel, JSON in one place:
from idf_objects.fenez.fenez_config_manager import build_fenez_config

# If you have geometry or shading Excel overrides, import them as well.

# --------------------------------------------------------------------------
# B) IDF creation & scenario modules
# --------------------------------------------------------------------------
from idf_creation import create_idfs_for_all_buildings
from main_modifi import run_modification_workflow

# --------------------------------------------------------------------------
# C) Validation
# --------------------------------------------------------------------------
from validation.main_validation import run_validation_process

# --------------------------------------------------------------------------
# D) Calibration, Sensitivity, Surrogate modules
# --------------------------------------------------------------------------
from cal.unified_calibration import run_unified_calibration


from cal.unified_sensitivity import run_sensitivity_analysis
from cal.unified_surrogate import (
    load_scenario_params as sur_load_scenario_params,
    pivot_scenario_params,
    filter_top_parameters,
    load_sim_results,
    aggregate_results,
    merge_params_with_results,
    build_and_save_surrogate
)

###############################################################################
# 1) Logging Setup
###############################################################################
def setup_logging(log_level=logging.INFO):
    logging.basicConfig(
        level=log_level,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return logging.getLogger(__name__)


###############################################################################
# 2) Utility: load JSON from file
###############################################################################
def load_json(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"JSON file not found: {filepath}")
    with open(filepath, "r") as f:
        return json.load(f)


###############################################################################
# 3) Main Orchestration
###############################################################################
def main():
    logger = setup_logging()
    logger.info("=== Starting main.py ===")

    # --------------------------------------------------------------------------
    # A) Load main_config.json
    # --------------------------------------------------------------------------
    user_configs_folder = r"D:\Documents\E_Plus_2030_py\user_configs"
    main_config_path = os.path.join(user_configs_folder, "main_config.json")

    if not os.path.isfile(main_config_path):
        logger.error(f"[ERROR] Cannot find main_config.json at {main_config_path}")
        return

    main_config = load_json(main_config_path)
    
    # Extract relevant sections
    paths_dict    = main_config.get("paths", {})
    excel_flags   = main_config.get("excel_overrides", {})
    user_flags    = main_config.get("user_config_overrides", {})
    def_dicts     = main_config.get("default_dicts", {})
    idf_cfg       = main_config.get("idf_creation", {})
    modification_cfg = main_config.get("modification", {})
    validation_cfg   = main_config.get("validation", {})
    sens_cfg         = main_config.get("sensitivity", {})
    sur_cfg          = main_config.get("surrogate", {})
    cal_cfg          = main_config.get("calibration", {})

    # --------------------------------------------------------------------------
    # B) Setup default dictionaries for each module
    # --------------------------------------------------------------------------
    # Fenestration
    base_res_data    = def_dicts.get("res_data", {})
    base_nonres_data = def_dicts.get("nonres_data", {})
    # Others
    dhw_lookup       = def_dicts.get("dhw", {})
    epw_lookup       = def_dicts.get("epw", [])
    lighting_lookup  = def_dicts.get("lighting", {})
    hvac_lookup      = def_dicts.get("hvac", {})
    vent_lookup      = def_dicts.get("vent", {})

    # --------------------------------------------------------------------------
    # C) Apply Excel-based overrides if flagged
    # --------------------------------------------------------------------------
    # 1) Fenestration via build_fenez_config => do_excel_override
    override_fenez_excel = excel_flags.get("override_fenez_excel", False)
    fenez_excel_path      = paths_dict.get("fenez_excel", "")

    # We'll *initially* call build_fenez_config with do_excel_override=override_fenez_excel
    # We won't pass user_fenez_overrides yet, or we'll pass an empty list. We'll do that below or unify it.
    # But a simpler approach is to also handle user_fenez_overrides here, see next step (D).
    # For now, let's do partial:
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=base_res_data,
        base_nonres_data=base_nonres_data,
        excel_path=fenez_excel_path,
        do_excel_override=override_fenez_excel,
        user_fenez_overrides=[]  # we might fill this in after loading fenestration.json below
    )

    # 2) DHW Excel
    if excel_flags.get("override_dhw_excel", False):
        dhw_lookup = override_dhw_lookup_from_excel_file(
            dhw_excel_path=paths_dict.get("dhw_excel", ""),
            default_dhw_lookup=dhw_lookup,
            override_dhw_flag=True
        )

    # 3) EPW Excel
    if excel_flags.get("override_epw_excel", False):
        epw_lookup = override_epw_lookup_from_excel_file(
            epw_excel_path=paths_dict.get("epw_excel", ""),
            epw_lookup=epw_lookup,
            override_epw_flag=True
        )

    # 4) Lighting Excel
    if excel_flags.get("override_lighting_excel", False):
        lighting_lookup = override_lighting_lookup_from_excel_file(
            lighting_excel_path=paths_dict.get("lighting_excel", ""),
            lighting_lookup=lighting_lookup,
            override_lighting_flag=True
        )

    # 5) HVAC Excel
    if excel_flags.get("override_hvac_excel", False):
        hvac_lookup = override_hvac_lookup_from_excel_file(
            hvac_excel_path=paths_dict.get("hvac_excel", ""),
            hvac_lookup=hvac_lookup,
            override_hvac_flag=True
        )

    # 6) Vent Excel
    if excel_flags.get("override_vent_excel", False):
        vent_lookup = override_vent_lookup_from_excel_file(
            vent_excel_path=paths_dict.get("vent_excel", ""),
            vent_lookup=vent_lookup,
            override_vent_flag=True
        )

    # --------------------------------------------------------------------------
    # D) Apply User JSON overrides if flagged
    #    For each module, if override_*_json = True, we load the separate file 
    #    (e.g. fenestration.json, dhw.json, etc.) and apply partial overrides.
    # --------------------------------------------------------------------------
    # 1) Fenestration user JSON
    override_fenez_json = user_flags.get("override_fenez_json", False)
    if override_fenez_json:
        fenestration_json_path = os.path.join(user_configs_folder, "fenestration.json")
        if os.path.isfile(fenestration_json_path):
            try:
                fenestration_data = load_json(fenestration_json_path)
            except Exception as e:
                fenestration_data = {}
                logger.error(f"Error loading fenestration.json: {e}")

            # Typically "fenestration_data" might be: { "fenestration": [ { ... }, {...} ] }
            user_fenez_overrides = fenestration_data.get("fenestration", [])
        else:
            logger.warning(f"[WARN] fenestration.json not found at {fenestration_json_path}. No user fenestration overrides.")
            user_fenez_overrides = []
    else:
        user_fenez_overrides = []

    # Now we re-run build_fenez_config so that it merges user_fenez_overrides 
    # with the already Excel-overridden dictionaries (updated_res_data, updated_nonres_data).
    # If you prefer to do it in one step, you can incorporate it directly in build_fenez_config. 
    # But here's a 2-step example:
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=updated_res_data,
        base_nonres_data=updated_nonres_data,
        excel_path="",             # no need to re-apply Excel
        do_excel_override=False,   # we already did that
        user_fenez_overrides=user_fenez_overrides
    )


    # 2) DHW user JSON
    override_dhw_json = user_flags.get("override_dhw_json", False)
    user_config_dhw = None  # We will store a list of overrides here
    if override_dhw_json:
        dhw_json_path = os.path.join(user_configs_folder, "dhw.json")
        if os.path.isfile(dhw_json_path):
            try:
                dhw_data = load_json(dhw_json_path)
                user_config_dhw = dhw_data.get("dhw", [])
            except Exception as e:
                logger.error(f"[ERROR] loading dhw.json => {e}")
                user_config_dhw = None
        else:
            logger.warning(f"[WARN] dhw.json not found at {dhw_json_path}")
            user_config_dhw = None
    else:
        user_config_dhw = None

    # 3) EPW user JSON
    override_epw_json = user_flags.get("override_epw_json", False)
    user_config_epw = []
    if override_epw_json:
        epw_json_path = os.path.join(user_configs_folder, "epw.json")
        if os.path.isfile(epw_json_path):
            epw_data = load_json(epw_json_path)
            user_config_epw = epw_data.get("epw", [])


    # 4) Lighting user JSON
    override_lighting_json = user_flags.get("override_lighting_json", False)
    user_config_lighting = None
    if override_lighting_json:
        lighting_json_path = os.path.join(user_configs_folder, "lighting.json")
        if os.path.isfile(lighting_json_path):
            try:
                lighting_data = load_json(lighting_json_path)
                user_config_lighting = lighting_data.get("lighting", [])
            except Exception as e:
                logger.error(f"[ERROR] loading lighting.json => {e}")
                user_config_lighting = None


    # 5) HVAC user JSON
    override_hvac_json = user_flags.get("override_hvac_json", False)
    if override_hvac_json:
        hvac_json_path = os.path.join(user_configs_folder, "hvac.json")
        hvac_data = load_json(hvac_json_path)
        user_config_hvac = hvac_data.get("hvac", [])
    else:
        user_config_hvac = None

    # 6) Vent user JSON
    override_vent_json = user_flags.get("override_vent_json", False)
    if override_vent_json:
        pass  # similarly handle vent.json

    # 7) Geometry user JSON
    override_geometry_json = user_flags.get("override_geometry_json", False)
    geometry_dict = {}
    if override_geometry_json:
        geometry_json_path = os.path.join(user_configs_folder, "geometry.json")
        if os.path.isfile(geometry_json_path):
            # load geometry config
            try:
                geom_data = load_json(geometry_json_path)
                from user_config_overrides import apply_geometry_user_config
                # e.g. if geom_data = { "geometry": [ {...} ] }
                geometry_dict = apply_geometry_user_config({}, geom_data.get("geometry", []))
            except Exception as e:
                logger.error(f"[ERROR] loading geometry.json => {e}")
        else:
            logger.warning(f"[WARN] geometry.json not found.")

    # 8) Shading user JSON
    override_shading_json = user_flags.get("override_shading_json", False)
    shading_dict = {}
    if override_shading_json:
        shading_json_path = os.path.join(user_configs_folder, "shading.json")
        if os.path.isfile(shading_json_path):
            # load shading config
            try:
                shading_data = load_json(shading_json_path)
                from user_config_overrides import apply_shading_user_config
                shading_dict = apply_shading_user_config({}, shading_data.get("shading", []))
            except Exception as e:
                logger.error(f"[ERROR] loading shading.json => {e}")
        else:
            logger.warning("[WARN] shading.json not found.")


    if override_vent_json:
        vent_json_path = os.path.join(user_configs_folder, "vent.json")
        if os.path.isfile(vent_json_path):
            vent_data = load_json(vent_json_path)
            user_config_vent = vent_data.get("vent", [])
        else:
            user_config_vent = []
    else:
        user_config_vent = []

    # --------------------------------------------------------------------------
    # E) IDF Creation (if enabled)
    # --------------------------------------------------------------------------
    if idf_cfg.get("perform_idf_creation", False):
        logger.info("[INFO] IDF creation is ENABLED.")

        # Load building data
        bldg_data_path = paths_dict.get("building_data", "")
        if os.path.isfile(bldg_data_path):
            df_buildings = pd.read_csv(bldg_data_path)
        else:
            logger.warning(f"[WARN] Building data CSV not found at {bldg_data_path}. Using empty DF.")
            df_buildings = pd.DataFrame()

        # Create IDFs
        create_idfs_for_all_buildings(
            df_buildings=df_buildings,
            scenario=idf_cfg.get("scenario", "scenario1"),
            calibration_stage=idf_cfg.get("calibration_stage", "pre_calibration"),
            strategy=idf_cfg.get("strategy", "B"),
            random_seed=idf_cfg.get("random_seed", 42),
            # geometry overrides
            user_config_geom=None if not override_geometry_json else geom_data.get("geometry", []),
            user_config_lighting=user_config_lighting,  # or load from your lighting approach above
            user_config_dhw=user_config_dhw,       # or dhw_data if needed
            # Instead of user_config_fenez, we pass the final fenestration dicts:
            res_data=updated_res_data,
            nonres_data=updated_nonres_data,
            user_config_hvac=user_config_hvac,      # or hvac_data if needed
            user_config_vent=user_config_vent,      # or vent_data if needed
            user_config_epw=user_config_epw,   # <--- Add this line

            run_simulations=idf_cfg.get("run_simulations", True),
            simulate_config={"num_workers": idf_cfg.get("num_workers", 4)},
            post_process=idf_cfg.get("post_process", True)
        )
    else:
        logger.info("[INFO] Skipping IDF creation per user config.")

    # --------------------------------------------------------------------------
    # F) Scenario Modification / Generation
    # --------------------------------------------------------------------------
    if modification_cfg.get("perform_modification", False):
        logger.info("[INFO] Scenario modification is ENABLED.")
        run_modification_workflow(modification_cfg["modify_config"])
    else:
        logger.info("[INFO] Skipping scenario modification.")

    # --------------------------------------------------------------------------
    # G) Global Validation
    # --------------------------------------------------------------------------
    if validation_cfg.get("perform_validation", False):
        logger.info("[INFO] Global Validation is ENABLED.")
        run_validation_process(validation_cfg["config"])
    else:
        logger.info("[INFO] Skipping global validation.")

    # --------------------------------------------------------------------------
    # H) Sensitivity Analysis
    # --------------------------------------------------------------------------
    if sens_cfg.get("perform_sensitivity", False):
        logger.info("[INFO] Sensitivity Analysis is ENABLED.")
        run_sensitivity_analysis(
            scenario_folder=sens_cfg["scenario_folder"],
            method=sens_cfg["method"],
            results_csv=sens_cfg.get("results_csv", ""),
            target_variable=sens_cfg.get("target_variable", ""),
            output_csv=sens_cfg.get("output_csv", "sensitivity_output.csv"),
            n_morris_trajectories=sens_cfg.get("n_morris_trajectories", 10),
            num_levels=sens_cfg.get("num_levels", 4),
            n_sobol_samples=sens_cfg.get("n_sobol_samples", 128)
        )
    else:
        logger.info("[INFO] Skipping sensitivity analysis.")

    # --------------------------------------------------------------------------
    # I) Surrogate Modeling
    # --------------------------------------------------------------------------
    if sur_cfg.get("perform_surrogate", False):
        logger.info("[INFO] Surrogate Modeling is ENABLED.")

        scenario_folder = sur_cfg["scenario_folder"]
        results_csv     = sur_cfg["results_csv"]
        target_var      = sur_cfg["target_variable"]
        model_out       = sur_cfg["model_out"]
        cols_out        = sur_cfg["cols_out"]
        test_size       = sur_cfg["test_size"]

        # 1) Load & pivot scenario params
        df_scen = sur_load_scenario_params(scenario_folder)
        pivot_df = pivot_scenario_params(df_scen)

        # 2) Optionally filter top parameters
        # pivot_df = filter_top_parameters(pivot_df, "morris_sensitivity.csv", top_n=5)

        # 3) Load & aggregate sim results
        df_sim = load_sim_results(results_csv)
        df_agg = aggregate_results(df_sim)

        # 4) Merge
        merged_df = merge_params_with_results(pivot_df, df_agg, target_var)

        # 5) Build & save surrogate
        rf_model, trained_cols = build_and_save_surrogate(
            df_data=merged_df,
            target_col=target_var,
            model_out_path=model_out,
            columns_out_path=cols_out,
            test_size=test_size,
            random_state=42
        )
        if rf_model:
            logger.info("[INFO] Surrogate model built & saved.")
        else:
            logger.warning("[WARN] Surrogate modeling failed or insufficient data.")
    else:
        logger.info("[INFO] Skipping surrogate modeling.")

    # --------------------------------------------------------------------------
    # J) Calibration
    # --------------------------------------------------------------------------
    # In main.py
    if cal_cfg.get("perform_calibration", False):
        logger.info("[INFO] Calibration steps are ENABLED.")
        run_unified_calibration(cal_cfg)
    else:
        logger.info("[INFO] Skipping calibration steps.")


###############################################################################
# 4) Script Entry
###############################################################################
if __name__ == "__main__":
    main()
# Out:
# 2025-02-01 22:34:25 [INFO] __main__: === Starting main.py ===
# 2025-02-01 22:34:25 [INFO] __main__: [INFO] IDF creation is ENABLED.
# 2025-02-01 22:34:25 [INFO] idf_creation: --- Creating IDF for building index 0, ogc_fid=4136730 ---
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core', 'Zone3_FrontPerimeter', 'Zone3_RightPerimeter', 'Zone3_RearPerimeter', 'Zone3_LeftPerimeter', 'Zone3_Core']
# [add_fenestration] Building: 4136730 => WWR=0.028, used Window1C
# [DEBUG lighting] bldg_id=4136730, type='Residential', matched overrides => [{'building_id': 4136730, 'param_name': 'lights_wm2', 'min_val': 18.0, 'max_val': 20.0}, {'building_type': 'Residential', 'param_name': 'tN', 'min_val': 10999, 'max_val': 11999}]
# [DHW] building_id=4136730, dhw_key=Detached House
#      occupant_count=1 daily_liters=45.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_0_UseFraction, MyDHW_0_Setpoint
#      WATERHEATER => MyDHW_0_WaterHeater, fuel=Electricity, eff=0.9
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136730.
# [VENT OVERRIDES] bldg=4136730, infiltration_base=100.36394267984579, year_factor=21.402501075522267, sys=A, f_ctrl=0.9223210738148823, fanP=0.0, hrv_eff=0.0, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136730, system=A, infiltration=3.827 m3/s, vent=0.035 m3/s, #zones=15
#    => Created infiltration for Zone1_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
# 2025-02-01 22:34:26 [INFO] idf_creation: --- Creating IDF for building index 1, ogc_fid=4136732 ---
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_0.idf
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core']
# [add_fenestration] Building: 4136732 => WWR=0.300, used Window1C
# [DEBUG lighting] bldg_id=4136732, type='Non-Residential', matched overrides => []
# 2025-02-01 22:34:26 [INFO] idf_creation: [create_idfs_for_all_buildings] => Running simulations ...
# 2025-02-01 22:34:26 [INFO] root: [simulate_all] Starting...
# 2025-02-01 22:34:26 [INFO] root: [simulate_all] Found 2 tasks. Using 4 workers.
# [DHW] building_id=4136732, dhw_key=Detached House
#      occupant_count=2 daily_liters=90.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_1_UseFraction, MyDHW_1_Setpoint
#      WATERHEATER => MyDHW_1_WaterHeater, fuel=Electricity, eff=0.9
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136732.
# [VENT OVERRIDES] bldg=4136732, infiltration_base=0.6278853596915768, year_factor=0.9050021510445334, sys=D, f_ctrl=0.7723210738148822, fanP=0.0, hrv_eff=0.7736471214164012, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136732, system=D, infiltration=0.004 m3/s, vent=0.093 m3/s, #zones=10
#    => Created infiltration for Zone1_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#       -> Zone1_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_Core IdealLoads has HRV = 0.77
#       -> Zone2_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_Core IdealLoads has HRV = 0.77
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_1.idf
# 2025-02-01 22:34:31 [INFO] root: [simulate_all] All simulations complete.
# 2025-02-01 22:34:31 [INFO] idf_creation: [create_idfs_for_all_buildings] => Post-processing results & writing logs ...
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_as_is.csv
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# 2025-02-01 22:34:33 [INFO] idf_creation: [create_idfs_for_all_buildings] => Done post-processing.
# 2025-02-01 22:34:33 [INFO] __main__: [INFO] Scenario modification is ENABLED.
# 2025-02-01 22:34:33 [INFO] main_modifi: [MODIFICATION] Starting scenario-based workflow...
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_daily_mean.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 456
#     452 ###############################################################################
#     453 # 4) Script Entry
#     454 ###############################################################################
#     455 if __name__ == "__main__":
# --> 456     main()
#
# Cell In[2], line 367, in main()
#     365 if modification_cfg.get("perform_modification", False):
#     366     logger.info("[INFO] Scenario modification is ENABLED.")
# --> 367     run_modification_workflow(modification_cfg["modify_config"])
#     368 else:
#     369     logger.info("[INFO] Skipping scenario modification.")
#
# File d:\Documents\E_Plus_2030_py\main_modifi.py:189, in run_modification_workflow(config)
#     187 df_hvac_zn  = None
#     188 if "hvac_building" in assigned_csvs and "hvac_zones" in assigned_csvs:
# --> 189     df_hvac_bld = load_assigned_csv(assigned_csvs["hvac_building"])
#     190     df_hvac_zn  = load_assigned_csv(assigned_csvs["hvac_zones"])
#     191 elif "hvac" in assigned_csvs:
#
# File d:\Documents\E_Plus_2030_py\modification\common_utils.py:31, in load_assigned_csv(csv_path)
#      20 """
#      21 Loads a generic CSV file containing assigned parameters for a building or zone.
#      22 For example:
#    (...)
#      28   A Pandas DataFrame with the file contents.
#      29 """
#      30 if not os.path.isfile(csv_path):
# ---> 31     raise FileNotFoundError(f"Cannot find CSV at: {csv_path}")
#      32 df = pd.read_csv(csv_path)
#      33 return df
#
# FileNotFoundError: Cannot find CSV at: output/assigned/assigned_hvac_building.csv

# %%
"""
main.py

Orchestrates the entire workflow:
  1) Loads main_config.json (which has two sets of override flags: 
     excel_overrides, user_config_overrides) plus a "structuring" section 
     for post-processing logs into structured CSVs.
  2) Applies Excel overrides if "override_*_excel" is True.
  3) Applies JSON overrides if "override_*_json" is True, 
     loading fenestration.json, dhw.json, etc.
  4) Creates base IDFs (optional), runs simulations & merges results (optional).
  5) If "perform_structuring" is true, restructures the assigned_* CSV logs 
     into more refined CSVs for scenario usage.
  6) If "perform_modification" is true, calls `run_modification_workflow` 
     to create scenario-based IDFs & run them.
  7) If "perform_validation" is true, calls global validation.
  8) If "perform_sensitivity" is true, runs a sensitivity analysis.
  9) If "perform_surrogate" is true, builds a surrogate model.
 10) If "perform_calibration" is true, does calibration steps using `run_unified_calibration`.
"""

import os
import json
import logging
import pandas as pd

# --------------------------------------------------------------------------
# A) Overriding modules (Excel + JSON partial overrides)
# --------------------------------------------------------------------------
from excel_overrides import (
    override_dhw_lookup_from_excel_file,
    override_epw_lookup_from_excel_file,
    override_lighting_lookup_from_excel_file,
    override_hvac_lookup_from_excel_file,
    override_vent_lookup_from_excel_file
)
from idf_objects.fenez.fenez_config_manager import build_fenez_config

# --------------------------------------------------------------------------
# B) IDF creation & scenario modules
# --------------------------------------------------------------------------
from idf_creation import create_idfs_for_all_buildings
from main_modifi import run_modification_workflow

# --------------------------------------------------------------------------
# C) Validation
# --------------------------------------------------------------------------
from validation.main_validation import run_validation_process

# --------------------------------------------------------------------------
# D) Calibration, Sensitivity, Surrogate modules
# --------------------------------------------------------------------------
from cal.unified_sensitivity import run_sensitivity_analysis
from cal.unified_surrogate import (
    load_scenario_params as sur_load_scenario_params,
    pivot_scenario_params,
    filter_top_parameters,
    load_sim_results,
    aggregate_results,
    merge_params_with_results,
    build_and_save_surrogate
)
# Import the new calibration entry point:
from cal.unified_calibration import run_unified_calibration


###############################################################################
# 1) Logging Setup
###############################################################################
def setup_logging(log_level=logging.INFO):
    logging.basicConfig(
        level=log_level,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return logging.getLogger(__name__)


###############################################################################
# 2) Utility: load JSON from file
###############################################################################
def load_json(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"JSON file not found: {filepath}")
    with open(filepath, "r") as f:
        return json.load(f)


###############################################################################
# 3) Main Orchestration
###############################################################################
def main():
    logger = setup_logging()
    logger.info("=== Starting main.py ===")

    # --------------------------------------------------------------------------
    # A) Load main_config.json
    # --------------------------------------------------------------------------
    user_configs_folder = r"D:\Documents\E_Plus_2030_py\user_configs"
    main_config_path = os.path.join(user_configs_folder, "main_config.json")

    if not os.path.isfile(main_config_path):
        logger.error(f"[ERROR] Cannot find main_config.json at {main_config_path}")
        return

    main_config = load_json(main_config_path)
    
    # Extract top-level sections
    paths_dict       = main_config.get("paths", {})
    excel_flags      = main_config.get("excel_overrides", {})
    user_flags       = main_config.get("user_config_overrides", {})
    def_dicts        = main_config.get("default_dicts", {})
    idf_cfg          = main_config.get("idf_creation", {})
    structuring_cfg  = main_config.get("structuring", {})
    modification_cfg = main_config.get("modification", {})
    validation_cfg   = main_config.get("validation", {})
    sens_cfg         = main_config.get("sensitivity", {})
    sur_cfg          = main_config.get("surrogate", {})
    cal_cfg          = main_config.get("calibration", {})

    # --------------------------------------------------------------------------
    # B) Setup default dictionaries (fenestration + others)
    # --------------------------------------------------------------------------
    base_res_data    = def_dicts.get("res_data", {})
    base_nonres_data = def_dicts.get("nonres_data", {})
    dhw_lookup       = def_dicts.get("dhw", {})
    epw_lookup       = def_dicts.get("epw", [])
    lighting_lookup  = def_dicts.get("lighting", {})
    hvac_lookup      = def_dicts.get("hvac", {})
    vent_lookup      = def_dicts.get("vent", {})

    # --------------------------------------------------------------------------
    # C) Excel-based overrides if flagged
    # --------------------------------------------------------------------------
    override_fenez_excel = excel_flags.get("override_fenez_excel", False)
    fenez_excel_path     = paths_dict.get("fenez_excel", "")

    # Build fenestration config from Excel (if enabled)
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=base_res_data,
        base_nonres_data=base_nonres_data,
        excel_path=fenez_excel_path,
        do_excel_override=override_fenez_excel,
        user_fenez_overrides=[]  # JSON overrides come next
    )

    # Other Excel overrides
    if excel_flags.get("override_dhw_excel", False):
        dhw_lookup = override_dhw_lookup_from_excel_file(
            dhw_excel_path=paths_dict.get("dhw_excel", ""),
            default_dhw_lookup=dhw_lookup,
            override_dhw_flag=True
        )
    if excel_flags.get("override_epw_excel", False):
        epw_lookup = override_epw_lookup_from_excel_file(
            epw_excel_path=paths_dict.get("epw_excel", ""),
            epw_lookup=epw_lookup,
            override_epw_flag=True
        )
    if excel_flags.get("override_lighting_excel", False):
        lighting_lookup = override_lighting_lookup_from_excel_file(
            lighting_excel_path=paths_dict.get("lighting_excel", ""),
            lighting_lookup=lighting_lookup,
            override_lighting_flag=True
        )
    if excel_flags.get("override_hvac_excel", False):
        hvac_lookup = override_hvac_lookup_from_excel_file(
            hvac_excel_path=paths_dict.get("hvac_excel", ""),
            hvac_lookup=hvac_lookup,
            override_hvac_flag=True
        )
    if excel_flags.get("override_vent_excel", False):
        vent_lookup = override_vent_lookup_from_excel_file(
            vent_excel_path=paths_dict.get("vent_excel", ""),
            vent_lookup=vent_lookup,
            override_vent_flag=True
        )

    # --------------------------------------------------------------------------
    # D) User JSON overrides if flagged
    # --------------------------------------------------------------------------
    # Fenestration
    override_fenez_json = user_flags.get("override_fenez_json", False)
    if override_fenez_json:
        fenestration_json_path = os.path.join(user_configs_folder, "fenestration.json")
        if os.path.isfile(fenestration_json_path):
            try:
                fen_data = load_json(fenestration_json_path)
                user_fenez_overrides = fen_data.get("fenestration", [])
            except Exception as e:
                logger.error(f"[ERROR] loading fenestration.json => {e}")
                user_fenez_overrides = []
        else:
            logger.warning(f"[WARN] fenestration.json not found at {fenestration_json_path}")
            user_fenez_overrides = []
    else:
        user_fenez_overrides = []

    # Re-apply fenestration config with user_fenez_overrides
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=updated_res_data,
        base_nonres_data=updated_nonres_data,
        excel_path="",
        do_excel_override=False,
        user_fenez_overrides=user_fenez_overrides
    )

    # DHW JSON
    override_dhw_json = user_flags.get("override_dhw_json", False)
    user_config_dhw = None
    if override_dhw_json:
        dhw_json_path = os.path.join(user_configs_folder, "dhw.json")
        if os.path.isfile(dhw_json_path):
            try:
                dhw_data = load_json(dhw_json_path)
                user_config_dhw = dhw_data.get("dhw", [])
            except Exception as e:
                logger.error(f"[ERROR] loading dhw.json => {e}")
                user_config_dhw = None

    # EPW JSON
    override_epw_json = user_flags.get("override_epw_json", False)
    user_config_epw = []
    if override_epw_json:
        epw_json_path = os.path.join(user_configs_folder, "epw.json")
        if os.path.isfile(epw_json_path):
            epw_data = load_json(epw_json_path)
            user_config_epw = epw_data.get("epw", [])

    # Lighting JSON
    override_lighting_json = user_flags.get("override_lighting_json", False)
    user_config_lighting = None
    if override_lighting_json:
        lighting_json_path = os.path.join(user_configs_folder, "lighting.json")
        if os.path.isfile(lighting_json_path):
            try:
                lighting_data = load_json(lighting_json_path)
                user_config_lighting = lighting_data.get("lighting", [])
            except Exception as e:
                logger.error(f"[ERROR] loading lighting.json => {e}")
                user_config_lighting = None

    # HVAC JSON
    override_hvac_json = user_flags.get("override_hvac_json", False)
    user_config_hvac = None
    if override_hvac_json:
        hvac_json_path = os.path.join(user_configs_folder, "hvac.json")
        if os.path.isfile(hvac_json_path):
            hvac_data = load_json(hvac_json_path)
            user_config_hvac = hvac_data.get("hvac", [])
        else:
            logger.warning("[WARN] hvac.json not found.")

    # Vent JSON
    override_vent_json = user_flags.get("override_vent_json", False)
    user_config_vent = []
    if override_vent_json:
        vent_json_path = os.path.join(user_configs_folder, "vent.json")
        if os.path.isfile(vent_json_path):
            vent_data = load_json(vent_json_path)
            user_config_vent = vent_data.get("vent", [])
        else:
            user_config_vent = []

    # Geometry JSON
    override_geometry_json = user_flags.get("override_geometry_json", False)
    geometry_dict = {}
    geom_data = {}
    if override_geometry_json:
        geometry_json_path = os.path.join(user_configs_folder, "geometry.json")
        if os.path.isfile(geometry_json_path):
            try:
                geom_data = load_json(geometry_json_path)
                from user_config_overrides import apply_geometry_user_config
                geometry_dict = apply_geometry_user_config({}, geom_data.get("geometry", []))
            except Exception as e:
                logger.error(f"[ERROR] loading geometry.json => {e}")

    # Shading JSON
    override_shading_json = user_flags.get("override_shading_json", False)
    shading_dict = {}
    if override_shading_json:
        shading_json_path = os.path.join(user_configs_folder, "shading.json")
        if os.path.isfile(shading_json_path):
            try:
                shading_data = load_json(shading_json_path)
                from user_config_overrides import apply_shading_user_config
                shading_dict = apply_shading_user_config({}, shading_data.get("shading", []))
            except Exception as e:
                logger.error(f"[ERROR] loading shading.json => {e}")

    # --------------------------------------------------------------------------
    # E) IDF Creation (if enabled)
    # --------------------------------------------------------------------------
    if idf_cfg.get("perform_idf_creation", False):
        logger.info("[INFO] IDF creation is ENABLED.")

        # Load building data
        bldg_data_path = paths_dict.get("building_data", "")
        if os.path.isfile(bldg_data_path):
            df_buildings = pd.read_csv(bldg_data_path)
        else:
            logger.warning(f"[WARN] Building data CSV not found at {bldg_data_path}. Using empty DF.")
            df_buildings = pd.DataFrame()

        create_idfs_for_all_buildings(
            df_buildings=df_buildings,
            scenario=idf_cfg.get("scenario", "scenario1"),
            calibration_stage=idf_cfg.get("calibration_stage", "pre_calibration"),
            strategy=idf_cfg.get("strategy", "B"),
            random_seed=idf_cfg.get("random_seed", 42),
            user_config_geom=geom_data.get("geometry", []) if override_geometry_json else None,
            user_config_lighting=user_config_lighting,
            user_config_dhw=user_config_dhw,
            res_data=updated_res_data,
            nonres_data=updated_nonres_data,
            user_config_hvac=user_config_hvac,
            user_config_vent=user_config_vent,
            user_config_epw=user_config_epw,  # if your create_idfs_for_all_buildings uses it
            run_simulations=idf_cfg.get("run_simulations", True),
            simulate_config={"num_workers": idf_cfg.get("num_workers", 4)},
            post_process=idf_cfg.get("post_process", True)
        )
    else:
        logger.info("[INFO] Skipping IDF creation per user config.")

    # --------------------------------------------------------------------------
    # F) Structuring Step
    # --------------------------------------------------------------------------
    if structuring_cfg.get("perform_structuring", False):
        logger.info("[INFO] Performing log structuring (fenestration, dhw, hvac, vent).")

        # 1) Fenestration
        from idf_objects.structuring.fenestration_structuring import transform_fenez_log_to_structured_with_ranges
        fenez_conf = structuring_cfg.get("fenestration", {})
        fenez_in   = fenez_conf.get("csv_in",  "output/assigned/assigned_fenez_params.csv")
        fenez_out  = fenez_conf.get("csv_out", "output/assigned/structured_fenez_params.csv")
        transform_fenez_log_to_structured_with_ranges(csv_input=fenez_in, csv_output=fenez_out)

        # 2) DHW
        from idf_objects.structuring.dhw_structuring import transform_dhw_log_to_structured
        dhw_conf = structuring_cfg.get("dhw", {})
        dhw_in   = dhw_conf.get("csv_in",  "output/assigned/assigned_dhw_params.csv")
        dhw_out  = dhw_conf.get("csv_out", "output/assigned/structured_dhw_params.csv")
        transform_dhw_log_to_structured(csv_input=dhw_in, csv_output=dhw_out)

        # 3) HVAC
        from idf_objects.structuring.flatten_hvac import flatten_hvac_data, parse_assigned_value
        hvac_conf = structuring_cfg.get("hvac", {})
        hvac_in   = hvac_conf.get("csv_in",    "output/assigned/assigned_hvac_params.csv")
        hvac_bld  = hvac_conf.get("build_out", "output/assigned/assigned_hvac_building.csv")
        hvac_zone = hvac_conf.get("zone_out",  "output/assigned/assigned_hvac_zones.csv")

        if os.path.isfile(hvac_in):
            df_hvac = pd.read_csv(hvac_in)
            df_hvac["assigned_value"] = df_hvac["assigned_value"].apply(parse_assigned_value)
            flatten_hvac_data(df_input=df_hvac, out_build_csv=hvac_bld, out_zone_csv=hvac_zone)
        else:
            logger.warning(f"[WARN] HVAC input CSV not found at {hvac_in}; skipping.")

        # 4) Vent
        from idf_objects.structuring.flatten_assigned_vent import flatten_ventilation_data, parse_assigned_value
        vent_conf = structuring_cfg.get("vent", {})
        vent_in   = vent_conf.get("csv_in",    "output/assigned/assigned_ventilation.csv")
        vent_bld  = vent_conf.get("build_out", "output/assigned/assigned_vent_building.csv")
        vent_zone = vent_conf.get("zone_out",  "output/assigned/assigned_vent_zones.csv")

        if os.path.isfile(vent_in):
            df_vent = pd.read_csv(vent_in)
            df_vent["assigned_value"] = df_vent["assigned_value"].apply(parse_assigned_value)
            flatten_ventilation_data(df_input=df_vent, out_build_csv=vent_bld, out_zone_csv=vent_zone)
        else:
            logger.warning(f"[WARN] Vent input CSV not found at {vent_in}; skipping.")
    else:
        logger.info("[INFO] Skipping structuring step (perform_structuring=false).")

    # --------------------------------------------------------------------------
    # G) Scenario Modification / Generation
    # --------------------------------------------------------------------------
    if modification_cfg.get("perform_modification", False):
        logger.info("[INFO] Scenario modification is ENABLED.")
        run_modification_workflow(modification_cfg["modify_config"])
    else:
        logger.info("[INFO] Skipping scenario modification.")

    # --------------------------------------------------------------------------
    # H) Global Validation
    # --------------------------------------------------------------------------
    if validation_cfg.get("perform_validation", False):
        logger.info("[INFO] Global Validation is ENABLED.")
        run_validation_process(validation_cfg["config"])
    else:
        logger.info("[INFO] Skipping global validation.")

    # --------------------------------------------------------------------------
    # I) Sensitivity Analysis
    # --------------------------------------------------------------------------
    if sens_cfg.get("perform_sensitivity", False):
        logger.info("[INFO] Sensitivity Analysis is ENABLED.")
        run_sensitivity_analysis(
            scenario_folder=sens_cfg["scenario_folder"],
            method=sens_cfg["method"],
            results_csv=sens_cfg.get("results_csv", ""),
            target_variable=sens_cfg.get("target_variable", ""),
            output_csv=sens_cfg.get("output_csv", "sensitivity_output.csv"),
            n_morris_trajectories=sens_cfg.get("n_morris_trajectories", 10),
            num_levels=sens_cfg.get("num_levels", 4),
            n_sobol_samples=sens_cfg.get("n_sobol_samples", 128)
        )
    else:
        logger.info("[INFO] Skipping sensitivity analysis.")

    # --------------------------------------------------------------------------
    # J) Surrogate Modeling
    # --------------------------------------------------------------------------
    if sur_cfg.get("perform_surrogate", False):
        logger.info("[INFO] Surrogate Modeling is ENABLED.")

        scenario_folder = sur_cfg["scenario_folder"]
        results_csv     = sur_cfg["results_csv"]
        target_var      = sur_cfg["target_variable"]
        model_out       = sur_cfg["model_out"]
        cols_out        = sur_cfg["cols_out"]
        test_size       = sur_cfg["test_size"]

        # 1) Load & pivot scenario params
        df_scen = sur_load_scenario_params(scenario_folder)
        pivot_df = pivot_scenario_params(df_scen)

        # 2) Optionally filter top parameters
        # pivot_df = filter_top_parameters(pivot_df, "morris_sensitivity.csv", top_n=5)

        # 3) Load & aggregate sim results
        df_sim = load_sim_results(results_csv)
        df_agg = aggregate_results(df_sim)

        # 4) Merge
        merged_df = merge_params_with_results(pivot_df, df_agg, target_var)

        # 5) Build & save surrogate
        rf_model, trained_cols = build_and_save_surrogate(
            df_data=merged_df,
            target_col=target_var,
            model_out_path=model_out,
            columns_out_path=cols_out,
            test_size=test_size,
            random_state=42
        )
        if rf_model:
            logger.info("[INFO] Surrogate model built & saved.")
        else:
            logger.warning("[WARN] Surrogate modeling failed or insufficient data.")
    else:
        logger.info("[INFO] Skipping surrogate modeling.")

    # --------------------------------------------------------------------------
    # K) Calibration
    # --------------------------------------------------------------------------
    if cal_cfg.get("perform_calibration", False):
        logger.info("[INFO] Calibration steps are ENABLED.")
        # Simply call run_unified_calibration with the entire cal_cfg
        run_unified_calibration(cal_cfg)
    else:
        logger.info("[INFO] Skipping calibration steps.")

    logger.info("=== End of main.py ===")


###############################################################################
# 4) Script Entry
###############################################################################
if __name__ == "__main__":
    main()
# Out:
# 2025-02-02 23:16:43 [INFO] __main__: === Starting main.py ===
# 2025-02-02 23:16:43 [INFO] __main__: [INFO] IDF creation is ENABLED.
# 2025-02-02 23:16:43 [INFO] idf_creation: --- Creating IDF for building index 0, ogc_fid=4136730 ---
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core', 'Zone3_FrontPerimeter', 'Zone3_RightPerimeter', 'Zone3_RearPerimeter', 'Zone3_LeftPerimeter', 'Zone3_Core']
# [add_fenestration] Building: 4136730 => WWR=0.028, used Window1C
# [DEBUG lighting] bldg_id=4136730, type='Residential', matched overrides => [{'building_id': 4136730, 'param_name': 'lights_wm2', 'min_val': 18.0, 'max_val': 20.0}, {'building_type': 'Residential', 'param_name': 'tN', 'min_val': 10999, 'max_val': 11999}]
# [DHW] building_id=4136730, dhw_key=Detached House
#      occupant_count=1 daily_liters=45.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_0_UseFraction, MyDHW_0_Setpoint
#      WATERHEATER => MyDHW_0_WaterHeater, fuel=Electricity, eff=0.9
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136730.
# [VENT OVERRIDES] bldg=4136730, infiltration_base=100.36394267984579, year_factor=21.402501075522267, sys=A, f_ctrl=0.9223210738148823, fanP=0.0, hrv_eff=0.0, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136730, system=A, infiltration=3.827 m3/s, vent=0.035 m3/s, #zones=15
#    => Created infiltration for Zone1_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# 2025-02-02 23:16:45 [INFO] idf_creation: --- Creating IDF for building index 1, ogc_fid=4136732 ---
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_0.idf
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core']
# [add_fenestration] Building: 4136732 => WWR=0.300, used Window1C
# [DEBUG lighting] bldg_id=4136732, type='Non-Residential', matched overrides => []
# [DHW] building_id=4136732, dhw_key=Detached House
#      occupant_count=2 daily_liters=90.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_1_UseFraction, MyDHW_1_Setpoint
#      WATERHEATER => MyDHW_1_WaterHeater, fuel=Electricity, eff=0.9
# 2025-02-02 23:16:45 [INFO] idf_creation: [create_idfs_for_all_buildings] => Running simulations ...
# 2025-02-02 23:16:45 [INFO] root: [simulate_all] Starting...
# 2025-02-02 23:16:45 [INFO] root: [simulate_all] Found 2 tasks. Using 4 workers.
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136732.
# [VENT OVERRIDES] bldg=4136732, infiltration_base=0.6278853596915768, year_factor=0.9050021510445334, sys=D, f_ctrl=0.7723210738148822, fanP=0.0, hrv_eff=0.7736471214164012, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136732, system=D, infiltration=0.004 m3/s, vent=0.093 m3/s, #zones=10
#    => Created infiltration for Zone1_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#       -> Zone1_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_Core IdealLoads has HRV = 0.77
#       -> Zone2_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_Core IdealLoads has HRV = 0.77
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_1.idf
# 2025-02-02 23:16:51 [INFO] root: [simulate_all] All simulations complete.
# 2025-02-02 23:16:51 [INFO] idf_creation: [create_idfs_for_all_buildings] => Post-processing results & writing logs ...
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg2.csv, Building 2
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg3.csv, Building 3
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg4.csv, Building 4
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_as_is.csv
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg2.csv, Building 2
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg3.csv, Building 3
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg4.csv, Building 4
# 2025-02-02 23:17:21 [INFO] idf_creation: [create_idfs_for_all_buildings] => Done post-processing.
# 2025-02-02 23:17:21 [INFO] __main__: [INFO] Performing log structuring (fenestration, dhw, hvac, vent).
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_daily_mean.csv
# 2025-02-02 23:17:22 [INFO] __main__: [INFO] Scenario modification is ENABLED.
# 2025-02-02 23:17:22 [INFO] main_modifi: [MODIFICATION] Starting scenario-based workflow...
# [transform_fenez_log_to_structured_with_ranges] => wrote: output/assigned/structured_fenez_params.csv
# [transform_dhw_log_to_structured] => Wrote structured CSV to output/assigned/structured_dhw_params.csv
# [INFO] Wrote building-level picks to output/assigned/assigned_hvac_building.csv (26 rows).
# [INFO] Wrote zone-level picks to output/assigned/assigned_hvac_zones.csv (150 rows).
# [INFO] Wrote building-level picks to output/assigned/assigned_vent_building.csv (32 rows).
# [INFO] Wrote zone-level picks to output/assigned/assigned_vent_zones.csv (200 rows).
# [create_hvac_scenarios] Wrote scenario HVAC params => output/scenarios/scenario_params_hvac.csv
# [create_dhw_scenarios] Wrote => output/scenarios/scenario_params_dhw.csv
# 2025-02-02 23:17:22 [INFO] main_modifi: [MODIFICATION] => Creating scenario #0 for building 4136730
# [create_vent_scenarios] Wrote scenario vent params => output/scenarios/scenario_params_vent.csv
# [create_elec_scenarios] Wrote scenario file => output/scenarios/scenario_params_elec.csv
# [create_fenez_scenarios] Wrote scenario params to output/scenarios/scenario_params_fenez.csv
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.639426798457883, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.223210738148822
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_0_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_0_Setpoint' = 58.446421476297644 °C all day.
# [DHW] Updated WaterHeater 'Scenario_0_WaterHeater' => Volume=0.253 m3, Capacity=4275.029318369119 W, SetpointSched=Scenario_0_Setpoint, FlowFracSched=Scenario_0_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.36394267984579, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.278853596915766, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# 2025-02-02 23:17:23 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_0.idf
# 2025-02-02 23:17:23 [INFO] main_modifi: [MODIFICATION] => Creating scenario #1 for building 4136730
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_0.idf
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.892179567704845, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.02979721943807
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_1_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_1_Setpoint' = 58.3976753013733 °C all day.
# [DHW] Updated WaterHeater 'Scenario_1_WaterHeater' => Volume=0.301 m3, Capacity=4026.5359696838636 W, SetpointSched=Scenario_1_Setpoint, FlowFracSched=Scenario_1_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.36766994874229, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=18.55005863673824, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# 2025-02-02 23:17:24 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_1.idf
# 2025-02-02 23:17:24 [INFO] main_modifi: [MODIFICATION] => Creating scenario #2 for building 4136730
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_1.idf
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.026535969683863, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.544941480603217
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_2_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_2_Setpoint' = 58.310958999623566 °C all day.
# [DHW] Updated WaterHeater 'Scenario_2_WaterHeater' => Volume=0.320 m3, Capacity=4340.250516517992 W, SetpointSched=Scenario_2_Setpoint, FlowFracSched=Scenario_2_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.32186379748036, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.472942428328025, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# 2025-02-02 23:17:25 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_2.idf
# 2025-02-02 23:17:25 [INFO] main_modifi: [MODIFICATION] => Creating scenario #3 for building 4136730
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_2.idf
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.809430456677827, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.698139394988228
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_3_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_3_Setpoint' = 59.946231527958744 °C all day.
# [DHW] Updated WaterHeater 'Scenario_3_WaterHeater' => Volume=0.323 m3, Capacity=4536.228091454701 W, SetpointSched=Scenario_3_Setpoint, FlowFracSched=Scenario_3_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.35449414806033, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.78435913540969, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# ...
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'system_type' => no numeric encoding for value: A
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_FrontPerimeter
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_FrontPerimeter
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_RightPerimeter
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_RightPerimeter
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_RearPerimeter
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_RearPerimeter
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_LeftPerimeter
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_LeftPerimeter
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_Core
# [WARNING] Skipping param 'Zone1_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_Core
# [WARNING] Skipping param 'Zone1_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_FrontPerimeter
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_FrontPerimeter
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_RightPerimeter
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_RightPerimeter
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_RearPerimeter
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_RearPerimeter
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_LeftPerimeter
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_LeftPerimeter
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_Core
# [WARNING] Skipping param 'Zone2_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_Core
# [WARNING] Skipping param 'Zone2_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_FrontPerimeter
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_FrontPerimeter
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_RightPerimeter
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_RightPerimeter
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_RearPerimeter
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_RearPerimeter
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_LeftPerimeter
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_LeftPerimeter
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# 2025-02-02 23:18:08 [INFO] __main__: [INFO] Surrogate Modeling is ENABLED.
# [INFO] Morris sensitivity results => multi_corr_sensitivity.csv
# d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# 2025-02-02 23:18:13 [INFO] __main__: [INFO] Surrogate model built & saved.
# 2025-02-02 23:18:13 [INFO] __main__: [INFO] Calibration steps are ENABLED.
# [Surrogate Training Summary]
# Best Params: {'n_estimators': 200, 'max_features': 0.5, 'max_depth': 20}
# Target='Heating:EnergyTransfer [J](Hourly)': Train R2=0.759,  Test R2=-27.796,  MAE=27235130.433
# [INFO] Saved surrogate model => heating_surrogate_model.joblib
# [INFO] Saved columns => heating_surrogate_columns.joblib
# [INFO] Filtering scenario params to top 10 from multi_corr_sensitivity.csv => ['dhw_heater_capacity_w', 'dhw_waterheater.Heater_Maximum_Capacity', 'LIGHTS_SCHEDULE__tN', 'default_heater_capacity_w', 'LIGHTS_SCHEDULE__tD', 'exterior_wall_opq__Density', 'inter_floor_opq__Specific_Heat', 'flat_roof_opq__Density', 'flat_roof_opq__Specific_Heat', 'ground_floor_opq__Specific_Heat']
# [INFO] Loading surrogate => heating_surrogate_model.joblib / heating_surrogate_columns.joblib
# [INFO] Loading real data => output/results/mock_merged_daily_mean.csv
# [GA] gen=0 best_error=30264663202.040
# [GA] gen=1 best_error=30264663202.040
# [GA] gen=2 best_error=30264663202.040
# [GA] gen=3 best_error=30264663202.040
# 2025-02-02 23:18:14 [INFO] __main__: === End of main.py ===
# [GA] gen=4 best_error=30264663202.040
# [CAL] Method=ga, Best error=30264663202.040, best_params={'scenario_params_dhw:default_heater_capacity_w_VAL': 4875.180556125417, 'scenario_params_dhw:default_heater_capacity_w_MIN': 2314.2175428167066, 'scenario_params_dhw:default_heater_capacity_w_MAX': 5165.355222539926, 'scenario_params_dhw:dhw_heater_capacity_w_VAL': 4033.006751392451, 'scenario_params_dhw:dhw_heater_capacity_w_MIN': 1400.3164897521704, 'scenario_params_dhw:dhw_heater_capacity_w_MAX': 9807.857655883889, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_VAL': 4075.8130356724387, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_MIN': 2063.8045905392505, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_MAX': 9782.052039126018}
# [INFO] Wrote calibration history => output/calibrated\calibration_history.csv
# [INFO] Wrote best params => output/calibrated\calibrated_params_scenario_params_dhw.csv
# [CAL] Calibration complete.

# %%
"""
main.py

Orchestrates the entire workflow:
  1) Loads main_config.json (which has two sets of override flags: 
     excel_overrides, user_config_overrides) plus a "structuring" section 
     for post-processing logs into structured CSVs.
  2) Applies Excel overrides if "override_*_excel" is True.
  3) Applies JSON overrides if "override_*_json" is True, 
     loading fenestration.json, dhw.json, etc.
  4) Creates base IDFs (optional), runs simulations & merges results (optional).
  5) If "perform_structuring" is true, restructures the assigned_* CSV logs 
     into more refined CSVs for scenario usage.
  6) If "perform_modification" is true, calls `run_modification_workflow` 
     to create scenario-based IDFs & run them.
  7) If "perform_validation" is true, calls global validation.
  8) If "perform_sensitivity" is true, runs a sensitivity analysis.
  9) If "perform_surrogate" is true, builds a surrogate model.
 10) If "perform_calibration" is true, does calibration steps using `run_unified_calibration`.
"""

import os
import json
import logging
import pandas as pd

# --------------------------------------------------------------------------
# A) Overriding modules (Excel + JSON partial overrides)
# --------------------------------------------------------------------------
from excel_overrides import (
    override_dhw_lookup_from_excel_file,
    override_epw_lookup_from_excel_file,
    override_lighting_lookup_from_excel_file,
    override_hvac_lookup_from_excel_file,
    override_vent_lookup_from_excel_file
)
from idf_objects.fenez.fenez_config_manager import build_fenez_config

# --------------------------------------------------------------------------
# B) IDF creation & scenario modules
# --------------------------------------------------------------------------
from idf_creation import create_idfs_for_all_buildings
from main_modifi import run_modification_workflow

# --------------------------------------------------------------------------
# C) Validation
# --------------------------------------------------------------------------
from validation.main_validation import run_validation_process

# --------------------------------------------------------------------------
# D) Calibration, Sensitivity, Surrogate modules
# --------------------------------------------------------------------------
from cal.unified_sensitivity import run_sensitivity_analysis
from cal.unified_surrogate import (
    load_scenario_params as sur_load_scenario_params,
    pivot_scenario_params,
    filter_top_parameters,
    load_sim_results,
    aggregate_results,
    merge_params_with_results,
    build_and_save_surrogate
)
# Import the new calibration entry point:
from cal.unified_calibration import run_unified_calibration


###############################################################################
# 1) Logging Setup
###############################################################################
def setup_logging(log_level=logging.INFO):
    logging.basicConfig(
        level=log_level,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return logging.getLogger(__name__)


###############################################################################
# 2) Utility: load JSON from file
###############################################################################
def load_json(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"JSON file not found: {filepath}")
    with open(filepath, "r") as f:
        return json.load(f)


###############################################################################
# 3) Main Orchestration
###############################################################################
def main():
    logger = setup_logging()
    logger.info("=== Starting main.py ===")

    # --------------------------------------------------------------------------
    # A) Load main_config.json
    # --------------------------------------------------------------------------
    user_configs_folder = r"D:\Documents\E_Plus_2030_py\user_configs"
    main_config_path = os.path.join(user_configs_folder, "main_config.json")

    if not os.path.isfile(main_config_path):
        logger.error(f"[ERROR] Cannot find main_config.json at {main_config_path}")
        return

    main_config = load_json(main_config_path)
    
    # Extract top-level sections
    paths_dict       = main_config.get("paths", {})
    excel_flags      = main_config.get("excel_overrides", {})
    user_flags       = main_config.get("user_config_overrides", {})
    def_dicts        = main_config.get("default_dicts", {})
    idf_cfg          = main_config.get("idf_creation", {})
    structuring_cfg  = main_config.get("structuring", {})
    modification_cfg = main_config.get("modification", {})
    validation_cfg   = main_config.get("validation", {})
    sens_cfg         = main_config.get("sensitivity", {})
    sur_cfg          = main_config.get("surrogate", {})
    cal_cfg          = main_config.get("calibration", {})

    # --------------------------------------------------------------------------
    # B) Setup default dictionaries (fenestration + others)
    # --------------------------------------------------------------------------
    base_res_data    = def_dicts.get("res_data", {})
    base_nonres_data = def_dicts.get("nonres_data", {})
    dhw_lookup       = def_dicts.get("dhw", {})
    epw_lookup       = def_dicts.get("epw", [])
    lighting_lookup  = def_dicts.get("lighting", {})
    hvac_lookup      = def_dicts.get("hvac", {})
    vent_lookup      = def_dicts.get("vent", {})

    # --------------------------------------------------------------------------
    # C) Excel-based overrides if flagged
    # --------------------------------------------------------------------------
    override_fenez_excel = excel_flags.get("override_fenez_excel", False)
    fenez_excel_path     = paths_dict.get("fenez_excel", "")

    # Build fenestration config from Excel (if enabled)
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=base_res_data,
        base_nonres_data=base_nonres_data,
        excel_path=fenez_excel_path,
        do_excel_override=override_fenez_excel,
        user_fenez_overrides=[]  # JSON overrides come next
    )

    # Other Excel overrides
    if excel_flags.get("override_dhw_excel", False):
        dhw_lookup = override_dhw_lookup_from_excel_file(
            dhw_excel_path=paths_dict.get("dhw_excel", ""),
            default_dhw_lookup=dhw_lookup,
            override_dhw_flag=True
        )
    if excel_flags.get("override_epw_excel", False):
        epw_lookup = override_epw_lookup_from_excel_file(
            epw_excel_path=paths_dict.get("epw_excel", ""),
            epw_lookup=epw_lookup,
            override_epw_flag=True
        )
    if excel_flags.get("override_lighting_excel", False):
        lighting_lookup = override_lighting_lookup_from_excel_file(
            lighting_excel_path=paths_dict.get("lighting_excel", ""),
            lighting_lookup=lighting_lookup,
            override_lighting_flag=True
        )
    if excel_flags.get("override_hvac_excel", False):
        hvac_lookup = override_hvac_lookup_from_excel_file(
            hvac_excel_path=paths_dict.get("hvac_excel", ""),
            hvac_lookup=hvac_lookup,
            override_hvac_flag=True
        )
    if excel_flags.get("override_vent_excel", False):
        vent_lookup = override_vent_lookup_from_excel_file(
            vent_excel_path=paths_dict.get("vent_excel", ""),
            vent_lookup=vent_lookup,
            override_vent_flag=True
        )

    # --------------------------------------------------------------------------
    # D) User JSON overrides if flagged
    # --------------------------------------------------------------------------
    # Fenestration
    override_fenez_json = user_flags.get("override_fenez_json", False)
    if override_fenez_json:
        fenestration_json_path = os.path.join(user_configs_folder, "fenestration.json")
        if os.path.isfile(fenestration_json_path):
            try:
                fen_data = load_json(fenestration_json_path)
                user_fenez_overrides = fen_data.get("fenestration", [])
            except Exception as e:
                logger.error(f"[ERROR] loading fenestration.json => {e}")
                user_fenez_overrides = []
        else:
            logger.warning(f"[WARN] fenestration.json not found at {fenestration_json_path}")
            user_fenez_overrides = []
    else:
        user_fenez_overrides = []

    # Re-apply fenestration config with user_fenez_overrides
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=updated_res_data,
        base_nonres_data=updated_nonres_data,
        excel_path="",
        do_excel_override=False,
        user_fenez_overrides=user_fenez_overrides
    )

    # DHW JSON
    override_dhw_json = user_flags.get("override_dhw_json", False)
    user_config_dhw = None
    if override_dhw_json:
        dhw_json_path = os.path.join(user_configs_folder, "dhw.json")
        if os.path.isfile(dhw_json_path):
            try:
                dhw_data = load_json(dhw_json_path)
                user_config_dhw = dhw_data.get("dhw", [])
            except Exception as e:
                logger.error(f"[ERROR] loading dhw.json => {e}")
                user_config_dhw = None

    # EPW JSON
    override_epw_json = user_flags.get("override_epw_json", False)
    user_config_epw = []
    if override_epw_json:
        epw_json_path = os.path.join(user_configs_folder, "epw.json")
        if os.path.isfile(epw_json_path):
            epw_data = load_json(epw_json_path)
            user_config_epw = epw_data.get("epw", [])

    # Lighting JSON
    override_lighting_json = user_flags.get("override_lighting_json", False)
    user_config_lighting = None
    if override_lighting_json:
        lighting_json_path = os.path.join(user_configs_folder, "lighting.json")
        if os.path.isfile(lighting_json_path):
            try:
                lighting_data = load_json(lighting_json_path)
                user_config_lighting = lighting_data.get("lighting", [])
            except Exception as e:
                logger.error(f"[ERROR] loading lighting.json => {e}")
                user_config_lighting = None

    # HVAC JSON
    override_hvac_json = user_flags.get("override_hvac_json", False)
    user_config_hvac = None
    if override_hvac_json:
        hvac_json_path = os.path.join(user_configs_folder, "hvac.json")
        if os.path.isfile(hvac_json_path):
            hvac_data = load_json(hvac_json_path)
            user_config_hvac = hvac_data.get("hvac", [])
        else:
            logger.warning("[WARN] hvac.json not found.")

    # Vent JSON
    override_vent_json = user_flags.get("override_vent_json", False)
    user_config_vent = []
    if override_vent_json:
        vent_json_path = os.path.join(user_configs_folder, "vent.json")
        if os.path.isfile(vent_json_path):
            vent_data = load_json(vent_json_path)
            user_config_vent = vent_data.get("vent", [])
        else:
            user_config_vent = []

    # Geometry JSON
    override_geometry_json = user_flags.get("override_geometry_json", False)
    geometry_dict = {}
    geom_data = {}
    if override_geometry_json:
        geometry_json_path = os.path.join(user_configs_folder, "geometry.json")
        if os.path.isfile(geometry_json_path):
            try:
                geom_data = load_json(geometry_json_path)
                from user_config_overrides import apply_geometry_user_config
                geometry_dict = apply_geometry_user_config({}, geom_data.get("geometry", []))
            except Exception as e:
                logger.error(f"[ERROR] loading geometry.json => {e}")

    # Shading JSON
    override_shading_json = user_flags.get("override_shading_json", False)
    shading_dict = {}
    if override_shading_json:
        shading_json_path = os.path.join(user_configs_folder, "shading.json")
        if os.path.isfile(shading_json_path):
            try:
                shading_data = load_json(shading_json_path)
                from user_config_overrides import apply_shading_user_config
                shading_dict = apply_shading_user_config({}, shading_data.get("shading", []))
            except Exception as e:
                logger.error(f"[ERROR] loading shading.json => {e}")

    # --------------------------------------------------------------------------
    # E) IDF Creation (if enabled)
    # --------------------------------------------------------------------------
    if idf_cfg.get("perform_idf_creation", False):
        logger.info("[INFO] IDF creation is ENABLED.")

        # Load building data
        bldg_data_path = paths_dict.get("building_data", "")
        if os.path.isfile(bldg_data_path):
            df_buildings = pd.read_csv(bldg_data_path)
        else:
            logger.warning(f"[WARN] Building data CSV not found at {bldg_data_path}. Using empty DF.")
            df_buildings = pd.DataFrame()

        create_idfs_for_all_buildings(
            df_buildings=df_buildings,
            scenario=idf_cfg.get("scenario", "scenario1"),
            calibration_stage=idf_cfg.get("calibration_stage", "pre_calibration"),
            strategy=idf_cfg.get("strategy", "B"),
            random_seed=idf_cfg.get("random_seed", 42),
            user_config_geom=geom_data.get("geometry", []) if override_geometry_json else None,
            user_config_lighting=user_config_lighting,
            user_config_dhw=user_config_dhw,
            res_data=updated_res_data,
            nonres_data=updated_nonres_data,
            user_config_hvac=user_config_hvac,
            user_config_vent=user_config_vent,
            user_config_epw=user_config_epw,  # if your create_idfs_for_all_buildings uses it
            run_simulations=idf_cfg.get("run_simulations", True),
            simulate_config={"num_workers": idf_cfg.get("num_workers", 4)},
            post_process=idf_cfg.get("post_process", True)
        )
    else:
        logger.info("[INFO] Skipping IDF creation per user config.")

    # --------------------------------------------------------------------------
    # F) Structuring Step
    # --------------------------------------------------------------------------
    if structuring_cfg.get("perform_structuring", False):
        logger.info("[INFO] Performing log structuring (fenestration, dhw, hvac, vent).")

        # 1) Fenestration
        from idf_objects.structuring.fenestration_structuring import transform_fenez_log_to_structured_with_ranges
        fenez_conf = structuring_cfg.get("fenestration", {})
        fenez_in   = fenez_conf.get("csv_in",  "output/assigned/assigned_fenez_params.csv")
        fenez_out  = fenez_conf.get("csv_out", "output/assigned/structured_fenez_params.csv")
        transform_fenez_log_to_structured_with_ranges(csv_input=fenez_in, csv_output=fenez_out)

        # 2) DHW
        from idf_objects.structuring.dhw_structuring import transform_dhw_log_to_structured
        dhw_conf = structuring_cfg.get("dhw", {})
        dhw_in   = dhw_conf.get("csv_in",  "output/assigned/assigned_dhw_params.csv")
        dhw_out  = dhw_conf.get("csv_out", "output/assigned/structured_dhw_params.csv")
        transform_dhw_log_to_structured(csv_input=dhw_in, csv_output=dhw_out)

        # 3) HVAC
        from idf_objects.structuring.flatten_hvac import flatten_hvac_data, parse_assigned_value
        hvac_conf = structuring_cfg.get("hvac", {})
        hvac_in   = hvac_conf.get("csv_in",    "output/assigned/assigned_hvac_params.csv")
        hvac_bld  = hvac_conf.get("build_out", "output/assigned/assigned_hvac_building.csv")
        hvac_zone = hvac_conf.get("zone_out",  "output/assigned/assigned_hvac_zones.csv")

        if os.path.isfile(hvac_in):
            df_hvac = pd.read_csv(hvac_in)
            df_hvac["assigned_value"] = df_hvac["assigned_value"].apply(parse_assigned_value)
            flatten_hvac_data(df_input=df_hvac, out_build_csv=hvac_bld, out_zone_csv=hvac_zone)
        else:
            logger.warning(f"[WARN] HVAC input CSV not found at {hvac_in}; skipping.")

        # 4) Vent
        from idf_objects.structuring.flatten_assigned_vent import flatten_ventilation_data, parse_assigned_value
        vent_conf = structuring_cfg.get("vent", {})
        vent_in   = vent_conf.get("csv_in",    "output/assigned/assigned_ventilation.csv")
        vent_bld  = vent_conf.get("build_out", "output/assigned/assigned_vent_building.csv")
        vent_zone = vent_conf.get("zone_out",  "output/assigned/assigned_vent_zones.csv")

        if os.path.isfile(vent_in):
            df_vent = pd.read_csv(vent_in)
            df_vent["assigned_value"] = df_vent["assigned_value"].apply(parse_assigned_value)
            flatten_ventilation_data(df_input=df_vent, out_build_csv=vent_bld, out_zone_csv=vent_zone)
        else:
            logger.warning(f"[WARN] Vent input CSV not found at {vent_in}; skipping.")
    else:
        logger.info("[INFO] Skipping structuring step (perform_structuring=false).")

    # --------------------------------------------------------------------------
    # G) Scenario Modification / Generation
    # --------------------------------------------------------------------------
    if modification_cfg.get("perform_modification", False):
        logger.info("[INFO] Scenario modification is ENABLED.")
        run_modification_workflow(modification_cfg["modify_config"])
    else:
        logger.info("[INFO] Skipping scenario modification.")

    # --------------------------------------------------------------------------
    # H) Global Validation
    # --------------------------------------------------------------------------
    if validation_cfg.get("perform_validation", False):
        logger.info("[INFO] Global Validation is ENABLED.")
        run_validation_process(validation_cfg["config"])
    else:
        logger.info("[INFO] Skipping global validation.")

    # --------------------------------------------------------------------------
    # I) Sensitivity Analysis
    # --------------------------------------------------------------------------
    if sens_cfg.get("perform_sensitivity", False):
        logger.info("[INFO] Sensitivity Analysis is ENABLED.")
        run_sensitivity_analysis(
            scenario_folder=sens_cfg["scenario_folder"],
            method=sens_cfg["method"],
            results_csv=sens_cfg.get("results_csv", ""),
            target_variable=sens_cfg.get("target_variable", ""),
            output_csv=sens_cfg.get("output_csv", "sensitivity_output.csv"),
            n_morris_trajectories=sens_cfg.get("n_morris_trajectories", 10),
            num_levels=sens_cfg.get("num_levels", 4),
            n_sobol_samples=sens_cfg.get("n_sobol_samples", 128)
        )
    else:
        logger.info("[INFO] Skipping sensitivity analysis.")

    # --------------------------------------------------------------------------
    # J) Surrogate Modeling
    # --------------------------------------------------------------------------
    if sur_cfg.get("perform_surrogate", False):
        logger.info("[INFO] Surrogate Modeling is ENABLED.")

        scenario_folder = sur_cfg["scenario_folder"]
        results_csv     = sur_cfg["results_csv"]
        target_var      = sur_cfg["target_variable"]
        model_out       = sur_cfg["model_out"]
        cols_out        = sur_cfg["cols_out"]
        test_size       = sur_cfg["test_size"]

        # 1) Load & pivot scenario params
        df_scen = sur_load_scenario_params(scenario_folder)
        pivot_df = pivot_scenario_params(df_scen)

        # 2) Optionally filter top parameters
        # pivot_df = filter_top_parameters(pivot_df, "morris_sensitivity.csv", top_n=5)

        # 3) Load & aggregate sim results
        df_sim = load_sim_results(results_csv)
        df_agg = aggregate_results(df_sim)

        # 4) Merge
        merged_df = merge_params_with_results(pivot_df, df_agg, target_var)

        # 5) Build & save surrogate
        rf_model, trained_cols = build_and_save_surrogate(
            df_data=merged_df,
            target_col=target_var,
            model_out_path=model_out,
            columns_out_path=cols_out,
            test_size=test_size,
            random_state=42
        )
        if rf_model:
            logger.info("[INFO] Surrogate model built & saved.")
        else:
            logger.warning("[WARN] Surrogate modeling failed or insufficient data.")
    else:
        logger.info("[INFO] Skipping surrogate modeling.")

    # --------------------------------------------------------------------------
    # K) Calibration
    # --------------------------------------------------------------------------
    if cal_cfg.get("perform_calibration", False):
        logger.info("[INFO] Calibration steps are ENABLED.")
        # Simply call run_unified_calibration with the entire cal_cfg
        run_unified_calibration(cal_cfg)
    else:
        logger.info("[INFO] Skipping calibration steps.")

    logger.info("=== End of main.py ===")


###############################################################################
# 4) Script Entry
###############################################################################
if __name__ == "__main__":
    main()
# Out:
# 2025-02-02 17:16:04 [INFO] __main__: === Starting main.py ===
# 2025-02-02 17:16:04 [INFO] __main__: [INFO] IDF creation is ENABLED.
# 2025-02-02 17:16:04 [INFO] idf_creation: --- Creating IDF for building index 0, ogc_fid=4136730 ---
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core', 'Zone3_FrontPerimeter', 'Zone3_RightPerimeter', 'Zone3_RearPerimeter', 'Zone3_LeftPerimeter', 'Zone3_Core']
# [add_fenestration] Building: 4136730 => WWR=0.028, used Window1C
# [DEBUG lighting] bldg_id=4136730, type='Residential', matched overrides => [{'building_id': 4136730, 'param_name': 'lights_wm2', 'min_val': 18.0, 'max_val': 20.0}, {'building_type': 'Residential', 'param_name': 'tN', 'min_val': 10999, 'max_val': 11999}]
# [DHW] building_id=4136730, dhw_key=Detached House
#      occupant_count=1 daily_liters=45.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_0_UseFraction, MyDHW_0_Setpoint
#      WATERHEATER => MyDHW_0_WaterHeater, fuel=Electricity, eff=0.9
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136730.
# [VENT OVERRIDES] bldg=4136730, infiltration_base=100.36394267984579, year_factor=21.402501075522267, sys=A, f_ctrl=0.9223210738148823, fanP=0.0, hrv_eff=0.0, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136730, system=A, infiltration=3.827 m3/s, vent=0.035 m3/s, #zones=15
#    => Created infiltration for Zone1_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# 2025-02-02 17:16:06 [INFO] idf_creation: --- Creating IDF for building index 1, ogc_fid=4136732 ---
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_0.idf
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core']
# [add_fenestration] Building: 4136732 => WWR=0.300, used Window1C
# [DEBUG lighting] bldg_id=4136732, type='Non-Residential', matched overrides => []
# [DHW] building_id=4136732, dhw_key=Detached House
#      occupant_count=2 daily_liters=90.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_1_UseFraction, MyDHW_1_Setpoint
#      WATERHEATER => MyDHW_1_WaterHeater, fuel=Electricity, eff=0.9
# 2025-02-02 17:16:07 [INFO] idf_creation: [create_idfs_for_all_buildings] => Running simulations ...
# 2025-02-02 17:16:07 [INFO] root: [simulate_all] Starting...
# 2025-02-02 17:16:07 [INFO] root: [simulate_all] Found 2 tasks. Using 4 workers.
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136732.
# [VENT OVERRIDES] bldg=4136732, infiltration_base=0.6278853596915768, year_factor=0.9050021510445334, sys=D, f_ctrl=0.7723210738148822, fanP=0.0, hrv_eff=0.7736471214164012, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136732, system=D, infiltration=0.004 m3/s, vent=0.093 m3/s, #zones=10
#    => Created infiltration for Zone1_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#       -> Zone1_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_Core IdealLoads has HRV = 0.77
#       -> Zone2_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_Core IdealLoads has HRV = 0.77
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_1.idf
# 2025-02-02 17:16:09 [INFO] root: [simulate_all] All simulations complete.
# 2025-02-02 17:16:09 [INFO] idf_creation: [create_idfs_for_all_buildings] => Post-processing results & writing logs ...
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg2.csv, Building 2
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg3.csv, Building 3
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg4.csv, Building 4
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_as_is.csv
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg2.csv, Building 2
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg3.csv, Building 3
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg4.csv, Building 4
# 2025-02-02 17:16:17 [INFO] idf_creation: [create_idfs_for_all_buildings] => Done post-processing.
# 2025-02-02 17:16:17 [INFO] __main__: [INFO] Performing log structuring (fenestration, dhw, hvac, vent).
# 2025-02-02 17:16:17 [INFO] __main__: [INFO] Scenario modification is ENABLED.
# 2025-02-02 17:16:17 [INFO] main_modifi: [MODIFICATION] Starting scenario-based workflow...
# [merge_all_results] Successfully wrote merged CSV to output/results/merged_daily_mean.csv
# [transform_fenez_log_to_structured_with_ranges] => wrote: output/assigned/structured_fenez_params.csv
# [transform_dhw_log_to_structured] => Wrote structured CSV to output/assigned/structured_dhw_params.csv
# [INFO] Wrote building-level picks to output/assigned/assigned_hvac_building.csv (26 rows).
# [INFO] Wrote zone-level picks to output/assigned/assigned_hvac_zones.csv (150 rows).
# [INFO] Wrote building-level picks to output/assigned/assigned_vent_building.csv (32 rows).
# [INFO] Wrote zone-level picks to output/assigned/assigned_vent_zones.csv (200 rows).
# [create_hvac_scenarios] Wrote scenario HVAC params => output/scenarios/scenario_params_hvac.csv
# [create_dhw_scenarios] Wrote => output/scenarios/scenario_params_dhw.csv
# [create_vent_scenarios] Wrote scenario vent params => output/scenarios/scenario_params_vent.csv
# [create_elec_scenarios] Wrote scenario file => output/scenarios/scenario_params_elec.csv
# [create_fenez_scenarios] Wrote scenario params to output/scenarios/scenario_params_fenez.csv
# 2025-02-02 17:16:17 [INFO] main_modifi: [MODIFICATION] => Creating scenario #0 for building 4136730
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_0.idf
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] => Creating scenario #1 for building 4136730
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.639426798457883, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.223210738148822
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=49.63105969982962, MinCool=13.353398974845822
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_0_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_0_Setpoint' = 58.446421476297644 °C all day.
# [DHW] Updated WaterHeater 'Scenario_0_WaterHeater' => Volume=0.253 m3, Capacity=4275.029318369119 W, SetpointSched=Scenario_0_Setpoint, FlowFracSched=Scenario_0_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.36394267984579, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.278853596915766, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_0.idf
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_1.idf
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] => Creating scenario #2 for building 4136730
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.892179567704845, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.02979721943807
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=48.90609316472504, MinCool=13.010710576206725
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_1_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_1_Setpoint' = 58.3976753013733 °C all day.
# [DHW] Updated WaterHeater 'Scenario_1_WaterHeater' => Volume=0.301 m3, Capacity=4026.5359696838636 W, SetpointSched=Scenario_1_Setpoint, FlowFracSched=Scenario_1_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.36766994874229, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=18.55005863673824, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_1.idf
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_2.idf
# 2025-02-02 17:16:18 [INFO] main_modifi: [MODIFICATION] => Creating scenario #3 for building 4136730
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.026535969683863, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.544941480603217
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=48.908616870856974, MinCool=13.178531367751818
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_2_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_2_Setpoint' = 58.310958999623566 °C all day.
# [DHW] Updated WaterHeater 'Scenario_2_WaterHeater' => Volume=0.320 m3, Capacity=4340.250516517992 W, SetpointSched=Scenario_2_Setpoint, FlowFracSched=Scenario_2_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.32186379748036, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.472942428328025, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ] Updated WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with new fields.
# [INFO] Saved modified IDF => output/scenario_idfs\building_4136730_scenario_2.idf
# 2025-02-02 17:16:19 [INFO] main_modifi: [MODIFICATION] Saved scenario IDF => output/scenario_idfs\building_4136730_scenario_3.idf
# 2025-02-02 17:16:19 [INFO] main_modifi: [MODIFICATION] => Creating scenario #4 for building 4136730
# [HVAC] Updated schedule 'ZONE HEATING SETPOINTS' with day=10.809430456677827, night=16.0
# [HVAC] Updated schedule 'ZONE COOLING SETPOINTS' with day=25.6, night=26.698139394988228
# [HVAC] Updated 'Zone1_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone1_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone2_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_FrontPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_RightPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_RearPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_LeftPerimeter Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] Updated 'Zone3_Core Ideal Loads' => MaxHeat=49.07635072312519, MinCool=12.310958999623564
# [HVAC] => Zone=Zone1_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_Core Ideal Loads' for zone Zone1_Core
# [HVAC] For zone=Zone1_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_FrontPerimeter Ideal Loads' for zone Zone1_FrontPerimeter
# [HVAC] For zone=Zone1_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_LeftPerimeter Ideal Loads' for zone Zone1_LeftPerimeter
# [HVAC] For zone=Zone1_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RearPerimeter Ideal Loads' for zone Zone1_RearPerimeter
# [HVAC] For zone=Zone1_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone1_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone1_RightPerimeter Ideal Loads' for zone Zone1_RightPerimeter
# [HVAC] For zone=Zone1_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_Core Ideal Loads' for zone Zone2_Core
# [HVAC] For zone=Zone2_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_FrontPerimeter Ideal Loads' for zone Zone2_FrontPerimeter
# [HVAC] For zone=Zone2_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_LeftPerimeter Ideal Loads' for zone Zone2_LeftPerimeter
# [HVAC] For zone=Zone2_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RearPerimeter Ideal Loads' for zone Zone2_RearPerimeter
# [HVAC] For zone=Zone2_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone2_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone2_RightPerimeter Ideal Loads' for zone Zone2_RightPerimeter
# [HVAC] For zone=Zone2_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_Core, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_Core Ideal Loads' for zone Zone3_Core
# [HVAC] For zone=Zone3_Core, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_FrontPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_FrontPerimeter Ideal Loads' for zone Zone3_FrontPerimeter
# [HVAC] For zone=Zone3_FrontPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_LeftPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_LeftPerimeter Ideal Loads' for zone Zone3_LeftPerimeter
# [HVAC] For zone=Zone3_LeftPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RearPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RearPerimeter Ideal Loads' for zone Zone3_RearPerimeter
# [HVAC] For zone=Zone3_RearPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [HVAC] => Zone=Zone3_RightPerimeter, 6 param rows
# [HVAC] Created or found ZONEHVAC:IDEALLOADSAIRSYSTEM => 'Zone3_RightPerimeter Ideal Loads' for zone Zone3_RightPerimeter
# [HVAC] For zone=Zone3_RightPerimeter, link heating_sched=ZONE HEATING SETPOINTS, cooling_sched=ZONE COOLING SETPOINTS
# [DHW] Created new fraction schedule 'Scenario_3_UseFraction' with standard blocks.
# [DHW] Created new setpoint schedule 'Scenario_3_Setpoint' = 59.946231527958744 °C all day.
# [DHW] Updated WaterHeater 'Scenario_3_WaterHeater' => Volume=0.323 m3, Capacity=4536.228091454701 W, SetpointSched=Scenario_3_Setpoint, FlowFracSched=Scenario_3_UseFraction, Fuel=Electricity, Eff=0.9, AmbientTempIndicator=Schedule
# [VENT] Applying building-level infiltration_base=100.35449414806033, schedule=AlwaysOnSched
# [VENT] => Zone=Zone1_Core, 8 param rows
# [VENT] => Zone=Zone1_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone1_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone1_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone2_Core, 8 param rows
# [VENT] => Zone=Zone2_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone2_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone2_RightPerimeter, 8 param rows
# [VENT] => Zone=Zone3_Core, 8 param rows
# [VENT] => Zone=Zone3_FrontPerimeter, 8 param rows
# [VENT] => Zone=Zone3_LeftPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RearPerimeter, 8 param rows
# [VENT] => Zone=Zone3_RightPerimeter, 8 param rows
# [ELEC] => Building-level electrical picks:
#   lights_wm2=19.78435913540969, parasitic_wm2=0.285
#   lights_frac_radiant=0.7, visible=0.2, replaceable=1.0
#   equip_frac_radiant=0.0, equip_frac_lost=1.0
#   schedules => lights=LightsSchedule, equip=ParasiticSchedule
# [FENEZ] Handling MATERIAL => 'Concrete_200mm' with 8 rows.
# [FENEZ] Updated MATERIAL => 'Concrete_200mm' with new fields.
# [FENEZ] Handling MATERIAL => 'DoorPanel_Range' with 16 rows.
# [FENEZ] Updated MATERIAL => 'DoorPanel_Range' with new fields.
# [FENEZ] Handling MATERIAL => 'InteriorWall_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InteriorWall_Generic' with new fields.
# [FENEZ] Handling MATERIAL => 'InternalFloor_Generic' with 8 rows.
# [FENEZ] Updated MATERIAL => 'InternalFloor_Generic' with new fields.
# [FENEZ] Handling MATERIAL:NOMASS => 'Insulated_Roof_R5' with 15 rows.
# [FENEZ] Updated MATERIAL:NOMASS => 'Insulated_Roof_R5' with new fields.
# [FENEZ] Handling WINDOWMATERIAL:GLAZING => 'Glazing_Clear_3mm' with 112 rows.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# [FENEZ WARNING] No direct field match for param_name='IR_Transmittance'. Skipping.
# ...
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'system_type' => no numeric encoding for value: A
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_FrontPerimeter
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_FrontPerimeter
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_RightPerimeter
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_RightPerimeter
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_RearPerimeter
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_RearPerimeter
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_LeftPerimeter
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_LeftPerimeter
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone1_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone1_Core
# [WARNING] Skipping param 'Zone1_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone1_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone1_Core
# [WARNING] Skipping param 'Zone1_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone1_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_FrontPerimeter
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_FrontPerimeter
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_RightPerimeter
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_RightPerimeter
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_RearPerimeter
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_RearPerimeter
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_LeftPerimeter
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_LeftPerimeter
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone2_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone2_Core
# [WARNING] Skipping param 'Zone2_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone2_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone2_Core
# [WARNING] Skipping param 'Zone2_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone2_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_FrontPerimeter
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_FrontPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_FrontPerimeter
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_FrontPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_RightPerimeter
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RightPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_RightPerimeter
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RightPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_RearPerimeter
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RearPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_RearPerimeter
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_RearPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_LeftPerimeter
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_LeftPerimeter
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_LeftPerimeter__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_name' => no numeric encoding for value: Infil_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__infiltration_object_type' => no numeric encoding for value: ZONEINFILTRATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__infiltration_schedule_name' => no numeric encoding for value: AlwaysOnSched
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_name' => no numeric encoding for value: Vent_residential_A_Zone3_Core
# [WARNING] Skipping param 'Zone3_Core__ventilation_object_type' => no numeric encoding for value: ZONEVENTILATION:DESIGNFLOWRATE
# [WARNING] Skipping param 'Zone3_Core__ventilation_schedule_name' => no numeric encoding for value: VentSched_DayNight
# 2025-02-02 17:16:41 [INFO] __main__: [INFO] Surrogate Modeling is ENABLED.
# [INFO] Morris sensitivity results => multi_corr_sensitivity.csv
# d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# 2025-02-02 17:16:45 [INFO] __main__: [INFO] Surrogate model built & saved.
# 2025-02-02 17:16:45 [INFO] __main__: [INFO] Calibration steps are ENABLED.
# [Surrogate Training Summary]
# Best Params: {'n_estimators': 200, 'max_features': 0.5, 'max_depth': 20}
# Target='Heating:EnergyTransfer [J](Hourly)': Train R2=0.759,  Test R2=-27.796,  MAE=27235130.433
# [INFO] Saved surrogate model => heating_surrogate_model.joblib
# [INFO] Saved columns => heating_surrogate_columns.joblib
# [INFO] Filtering scenario params to top 10 from multi_corr_sensitivity.csv => ['dhw_waterheater.Heater_Maximum_Capacity', 'dhw_heater_capacity_w', 'LIGHTS_SCHEDULE__tN', 'default_heater_capacity_w', 'LIGHTS_SCHEDULE__tD', 'exterior_wall_opq__Density', 'ground_floor_opq__Specific_Heat', 'flat_roof_opq__Specific_Heat', 'inter_floor_opq__Specific_Heat', 'flat_roof_opq__Density']
# [INFO] Loading surrogate => heating_surrogate_model.joblib / heating_surrogate_columns.joblib
# [INFO] Loading real data => output/results/mock_merged_daily_mean.csv
# [GA] gen=0 best_error=30264663202.040
# 2025-02-02 17:16:46 [INFO] __main__: === End of main.py ===
# [GA] gen=1 best_error=30264663202.040
# [GA] gen=2 best_error=30264663202.040
# [GA] gen=3 best_error=30264663202.040
# [GA] gen=4 best_error=30264663202.040
# [CAL] Method=ga, Best error=30264663202.040, best_params={'scenario_params_dhw:default_heater_capacity_w_VAL': 4875.180556125417, 'scenario_params_dhw:default_heater_capacity_w_MIN': 2314.2175428167066, 'scenario_params_dhw:default_heater_capacity_w_MAX': 5165.355222539926, 'scenario_params_dhw:dhw_heater_capacity_w_VAL': 4033.006751392451, 'scenario_params_dhw:dhw_heater_capacity_w_MIN': 1400.3164897521704, 'scenario_params_dhw:dhw_heater_capacity_w_MAX': 9807.857655883889, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_VAL': 4075.8130356724387, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_MIN': 2063.8045905392505, 'scenario_params_dhw:dhw_waterheater.Heater_Maximum_Capacity_MAX': 9782.052039126018}
# [INFO] Wrote calibration history => output/calibrated\calibration_history.csv
# [INFO] Wrote best params => output/calibrated\calibrated_params_scenario_params_dhw.csv
# [CAL] Calibration complete.

# %% [markdown]
# # # 3

# %%
"""
main.py

Orchestrates the entire workflow:
  1) Loads main_config.json (which has Excel override flags, user_config_override flags,
     "default_dicts", "idf_creation" configs, etc.).
  2) Applies Excel overrides if "override_*_excel" is True.
  3) Applies JSON overrides if "override_*_json" is True, loading fenestration.json, dhw.json, etc.
  4) Creates base IDFs (optional), runs simulations & merges results (optional) with new
     multi-step post-processing from "outputs" array.
  5) If "perform_structuring" is true, restructures the assigned_* CSV logs.
  6) If "perform_modification" is true, calls `run_modification_workflow`.
  7) If "perform_validation" is true, calls global validation.
  8) If "perform_sensitivity" is true, runs a sensitivity analysis.
  9) If "perform_surrogate" is true, builds a surrogate model.
 10) If "perform_calibration" is true, executes calibration steps.
"""

import os
import json
import logging
import pandas as pd

# Database loader (if "use_database": true)
from database_handler import load_buildings_from_db

# Excel overrides
from excel_overrides import (
    override_dhw_lookup_from_excel_file,
    override_epw_lookup_from_excel_file,
    override_lighting_lookup_from_excel_file,
    override_hvac_lookup_from_excel_file,
    override_vent_lookup_from_excel_file
)
from idf_objects.fenez.fenez_config_manager import build_fenez_config

# IDF creation & scenario modules
import idf_creation  # We'll override idf_creation.idf_config with environment variables or user JSON
from idf_creation import create_idfs_for_all_buildings
from main_modifi import run_modification_workflow

# Validation
from validation.main_validation import run_validation_process

# Calibration, Sensitivity, Surrogate modules
from cal.unified_sensitivity import run_sensitivity_analysis
from cal.unified_surrogate import (
    load_scenario_params as sur_load_scenario_params,
    pivot_scenario_params,
    filter_top_parameters,
    load_sim_results,
    aggregate_results,
    merge_params_with_results,
    build_and_save_surrogate
)
from cal.unified_calibration import run_unified_calibration


###############################################################################
# 1) Logging Setup
###############################################################################
def setup_logging(log_level=logging.INFO):
    logging.basicConfig(
        level=log_level,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )
    return logging.getLogger(__name__)


###############################################################################
# 2) Utility: load JSON from file
###############################################################################
def load_json(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"JSON file not found: {filepath}")
    with open(filepath, "r") as f:
        return json.load(f)


###############################################################################
# 3) Main Orchestration
###############################################################################
def main():
    logger = setup_logging()
    logger.info("=== Starting main.py ===")

    # --------------------------------------------------------------------------
    # A) Load main_config.json from user_configs (or your chosen location)
    # --------------------------------------------------------------------------
    current_dir = os.getcwd() # path.dirname(__file__)
    user_configs_folder = os.path.join(current_dir, "user_configs")
    main_config_path = os.path.join(user_configs_folder, "main_config.json")

    if not os.path.isfile(main_config_path):
        logger.error(f"[ERROR] Cannot find main_config.json at {main_config_path}")
        return

    main_config = load_json(main_config_path)

    # --------------------------------------------------------------------------
    # B) Override idf_creation config with environment variables (optional)
    #    or directly from main_config["idf_creation"]
    # --------------------------------------------------------------------------
    # 1) Environment variables approach (optional):
    env_idd_path = os.environ.get("IDD_PATH")
    if env_idd_path:
        idf_creation.idf_config["iddfile"] = env_idd_path

    env_base_idf = os.environ.get("BASE_IDF_PATH")
    if env_base_idf:
        idf_creation.idf_config["idf_file_path"] = env_base_idf

    env_out_dir = os.environ.get("OUTPUT_DIR")
    if env_out_dir:
        out_idf_dir = os.path.join(env_out_dir, "output_IDFs")
        idf_creation.idf_config["output_dir"] = out_idf_dir

    # 2) Reading user overrides from main_config["idf_creation"]
    idf_cfg = main_config.get("idf_creation", {})

    #   - IDD
    custom_idd = idf_cfg.get("iddfile")
    if custom_idd:
        idf_creation.idf_config["iddfile"] = custom_idd

    #   - Base IDF
    custom_base_idf = idf_cfg.get("idf_file_path")
    if custom_base_idf:
        idf_creation.idf_config["idf_file_path"] = custom_base_idf

    #   - IDF output directory
    custom_out_dir = idf_cfg.get("output_idf_dir")
    if custom_out_dir:
        idf_creation.idf_config["output_dir"] = custom_out_dir

    # --------------------------------------------------------------------------
    # Extract top-level sections from main_config
    # --------------------------------------------------------------------------
    paths_dict       = main_config.get("paths", {})
    excel_flags      = main_config.get("excel_overrides", {})
    user_flags       = main_config.get("user_config_overrides", {})
    def_dicts        = main_config.get("default_dicts", {})
    structuring_cfg  = main_config.get("structuring", {})
    modification_cfg = main_config.get("modification", {})
    validation_cfg   = main_config.get("validation", {})
    sens_cfg         = main_config.get("sensitivity", {})
    sur_cfg          = main_config.get("surrogate", {})
    cal_cfg          = main_config.get("calibration", {})

    # From idf_creation config
    perform_idf_creation   = idf_cfg.get("perform_idf_creation", False)
    scenario               = idf_cfg.get("scenario", "scenario1")
    calibration_stage      = idf_cfg.get("calibration_stage", "pre_calibration")
    strategy               = idf_cfg.get("strategy", "B")
    random_seed            = idf_cfg.get("random_seed", 42)
    run_simulations        = idf_cfg.get("run_simulations", True)
    simulate_config        = idf_cfg.get("simulate_config", {})
    post_process           = idf_cfg.get("post_process", True)
    post_process_config    = idf_cfg.get("post_process_config", {})
    output_definitions     = idf_cfg.get("output_definitions", {})

    use_database           = main_config.get("use_database", False)
    db_filter              = main_config.get("db_filter", {})

    # --------------------------------------------------------------------------
    # C) Setup default dictionaries for fenestration, DHW, EPW, lighting, etc.
    # --------------------------------------------------------------------------
    base_res_data    = def_dicts.get("res_data", {})
    base_nonres_data = def_dicts.get("nonres_data", {})
    dhw_lookup       = def_dicts.get("dhw", {})
    epw_lookup       = def_dicts.get("epw", [])
    lighting_lookup  = def_dicts.get("lighting", {})
    hvac_lookup      = def_dicts.get("hvac", {})
    vent_lookup      = def_dicts.get("vent", {})

    # --------------------------------------------------------------------------
    # D) Excel-based overrides if flagged
    # --------------------------------------------------------------------------
    override_fenez_excel = excel_flags.get("override_fenez_excel", False)
    fenez_excel_path     = paths_dict.get("fenez_excel", "")

    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=base_res_data,
        base_nonres_data=base_nonres_data,
        excel_path=fenez_excel_path,
        do_excel_override=override_fenez_excel,
        user_fenez_overrides=[]  # We'll set user overrides below if needed
    )

    if excel_flags.get("override_dhw_excel", False):
        dhw_lookup = override_dhw_lookup_from_excel_file(
            dhw_excel_path=paths_dict.get("dhw_excel", ""),
            default_dhw_lookup=dhw_lookup,
            override_dhw_flag=True
        )
    if excel_flags.get("override_epw_excel", False):
        epw_lookup = override_epw_lookup_from_excel_file(
            epw_excel_path=paths_dict.get("epw_excel", ""),
            epw_lookup=epw_lookup,
            override_epw_flag=True
        )
    if excel_flags.get("override_lighting_excel", False):
        lighting_lookup = override_lighting_lookup_from_excel_file(
            lighting_excel_path=paths_dict.get("lighting_excel", ""),
            lighting_lookup=lighting_lookup,
            override_lighting_flag=True
        )
    if excel_flags.get("override_hvac_excel", False):
        hvac_lookup = override_hvac_lookup_from_excel_file(
            hvac_excel_path=paths_dict.get("hvac_excel", ""),
            hvac_lookup=hvac_lookup,
            override_hvac_flag=True
        )
    if excel_flags.get("override_vent_excel", False):
        vent_lookup = override_vent_lookup_from_excel_file(
            vent_excel_path=paths_dict.get("vent_excel", ""),
            vent_lookup=vent_lookup,
            override_vent_flag=True
        )

    # --------------------------------------------------------------------------
    # E) User JSON overrides if flagged (fenestration, dhw, epw, lighting, hvac, vent, geometry, shading)
    # --------------------------------------------------------------------------
    user_fenez_overrides = []
    if user_flags.get("override_fenez_json", False):
        fenestration_json_path = os.path.join(user_configs_folder, "fenestration.json")
        if os.path.isfile(fenestration_json_path):
            try:
                fen_data = load_json(fenestration_json_path)
                user_fenez_overrides = fen_data.get("fenestration", [])
            except Exception as e:
                logger.error(f"[ERROR] loading fenestration.json => {e}")

    # Re-apply fenestration config with user_fenez_overrides
    updated_res_data, updated_nonres_data = build_fenez_config(
        base_res_data=updated_res_data,
        base_nonres_data=updated_nonres_data,
        excel_path="",
        do_excel_override=False,
        user_fenez_overrides=user_fenez_overrides
    )

    user_config_dhw = None
    if user_flags.get("override_dhw_json", False):
        dhw_json_path = os.path.join(user_configs_folder, "dhw.json")
        if os.path.isfile(dhw_json_path):
            try:
                dhw_data = load_json(dhw_json_path)
                user_config_dhw = dhw_data.get("dhw", [])
            except Exception as e:
                logger.error(f"[ERROR] loading dhw.json => {e}")

    user_config_epw = []
    if user_flags.get("override_epw_json", False):
        epw_json_path = os.path.join(user_configs_folder, "epw.json")
        if os.path.isfile(epw_json_path):
            epw_data = load_json(epw_json_path)
            user_config_epw = epw_data.get("epw", [])

    user_config_lighting = None
    if user_flags.get("override_lighting_json", False):
        lighting_json_path = os.path.join(user_configs_folder, "lighting.json")
        if os.path.isfile(lighting_json_path):
            try:
                lighting_data = load_json(lighting_json_path)
                user_config_lighting = lighting_data.get("lighting", [])
            except Exception as e:
                logger.error(f"[ERROR] loading lighting.json => {e}")

    user_config_hvac = None
    if user_flags.get("override_hvac_json", False):
        hvac_json_path = os.path.join(user_configs_folder, "hvac.json")
        if os.path.isfile(hvac_json_path):
            hvac_data = load_json(hvac_json_path)
            user_config_hvac = hvac_data.get("hvac", [])

    user_config_vent = []
    if user_flags.get("override_vent_json", False):
        vent_json_path = os.path.join(user_configs_folder, "vent.json")
        if os.path.isfile(vent_json_path):
            vent_data = load_json(vent_json_path)
            user_config_vent = vent_data.get("vent", [])

    geometry_dict = {}
    geom_data = {}
    if user_flags.get("override_geometry_json", False):
        geometry_json_path = os.path.join(user_configs_folder, "geometry.json")
        if os.path.isfile(geometry_json_path):
            try:
                geom_data = load_json(geometry_json_path)
                # For example, if you have a helper function in user_config_overrides:
                from user_config_overrides import apply_geometry_user_config
                geometry_dict = apply_geometry_user_config({}, geom_data.get("geometry", []))
            except Exception as e:
                logger.error(f"[ERROR] loading geometry.json => {e}")

    shading_dict = {}
    if user_flags.get("override_shading_json", False):
        shading_json_path = os.path.join(user_configs_folder, "shading.json")
        if os.path.isfile(shading_json_path):
            try:
                shading_data = load_json(shading_json_path)
                from user_config_overrides import apply_shading_user_config
                shading_dict = apply_shading_user_config({}, shading_data.get("shading", []))
            except Exception as e:
                logger.error(f"[ERROR] loading shading.json => {e}")

    # --------------------------------------------------------------------------
    # F) IDF Creation (if enabled) => create base IDFs + run sims + post-process
    # --------------------------------------------------------------------------
    if perform_idf_creation:
        logger.info("[INFO] IDF creation is ENABLED.")

        # 1) Get building DataFrame
        if use_database:
            logger.info("[INFO] Loading building data from PostgreSQL using filters.")
            df_buildings = load_buildings_from_db(db_filter)
            if df_buildings.empty:
                logger.warning("[WARN] No buildings returned from DB filters. Using empty DataFrame.")
        else:
            bldg_data_path = paths_dict.get("building_data", "")
            if os.path.isfile(bldg_data_path):
                df_buildings = pd.read_csv(bldg_data_path)
            else:
                logger.warning(f"[WARN] Building data CSV not found at {bldg_data_path}. Using empty DF.")
                df_buildings = pd.DataFrame()

        # 2) Create IDFs
        create_idfs_for_all_buildings(
            df_buildings=df_buildings,
            scenario=scenario,
            calibration_stage=calibration_stage,
            strategy=strategy,
            random_seed=random_seed,
            user_config_geom=geom_data.get("geometry", []),
            user_config_lighting=user_config_lighting,
            user_config_dhw=user_config_dhw,
            res_data=updated_res_data,
            nonres_data=updated_nonres_data,
            user_config_hvac=user_config_hvac,
            user_config_vent=user_config_vent,
            user_config_epw=user_config_epw,   # if your simulation uses it
            output_definitions=output_definitions,
            run_simulations=run_simulations,
            simulate_config=simulate_config,
            post_process=post_process,
            post_process_config=post_process_config
        )
    else:
        logger.info("[INFO] Skipping IDF creation per user config.")

    # --------------------------------------------------------------------------
    # G) Structuring Step (if enabled)
    # --------------------------------------------------------------------------
    if structuring_cfg.get("perform_structuring", False):
        logger.info("[INFO] Performing log structuring (fenestration, dhw, hvac, vent).")

        # Fenestration
        from idf_objects.structuring.fenestration_structuring import transform_fenez_log_to_structured_with_ranges
        fenez_conf = structuring_cfg.get("fenestration", {})
        fenez_in   = fenez_conf.get("csv_in",  "output/assigned/assigned_fenez_params.csv")
        fenez_out  = fenez_conf.get("csv_out", "output/assigned/structured_fenez_params.csv")
        transform_fenez_log_to_structured_with_ranges(csv_input=fenez_in, csv_output=fenez_out)

        # DHW
        from idf_objects.structuring.dhw_structuring import transform_dhw_log_to_structured
        dhw_conf = structuring_cfg.get("dhw", {})
        dhw_in   = dhw_conf.get("csv_in",  "output/assigned/assigned_dhw_params.csv")
        dhw_out  = dhw_conf.get("csv_out", "output/assigned/structured_dhw_params.csv")
        transform_dhw_log_to_structured(csv_input=dhw_in, csv_output=dhw_out)

        # HVAC
        from idf_objects.structuring.flatten_hvac import flatten_hvac_data, parse_assigned_value
        hvac_conf = structuring_cfg.get("hvac", {})
        hvac_in   = hvac_conf.get("csv_in",    "output/assigned/assigned_hvac_params.csv")
        hvac_bld  = hvac_conf.get("build_out", "output/assigned/assigned_hvac_building.csv")
        hvac_zone = hvac_conf.get("zone_out",  "output/assigned/assigned_hvac_zones.csv")

        if os.path.isfile(hvac_in):
            df_hvac = pd.read_csv(hvac_in)
            df_hvac["assigned_value"] = df_hvac["assigned_value"].apply(parse_assigned_value)
            flatten_hvac_data(df_input=df_hvac, out_build_csv=hvac_bld, out_zone_csv=hvac_zone)
        else:
            logger.warning(f"[WARN] HVAC input CSV not found at {hvac_in}; skipping.")

        # Vent
        from idf_objects.structuring.flatten_assigned_vent import flatten_ventilation_data, parse_assigned_value
        vent_conf = structuring_cfg.get("vent", {})
        vent_in   = vent_conf.get("csv_in",    "output/assigned/assigned_ventilation.csv")
        vent_bld  = vent_conf.get("build_out", "output/assigned/assigned_vent_building.csv")
        vent_zone = vent_conf.get("zone_out",  "output/assigned/assigned_vent_zones.csv")

        if os.path.isfile(vent_in):
            df_vent = pd.read_csv(vent_in)
            df_vent["assigned_value"] = df_vent["assigned_value"].apply(parse_assigned_value)
            flatten_ventilation_data(df_input=df_vent, out_build_csv=vent_bld, out_zone_csv=vent_zone)
        else:
            logger.warning(f"[WARN] Vent input CSV not found at {vent_in}; skipping.")
    else:
        logger.info("[INFO] Skipping structuring step (perform_structuring=false).")

    # --------------------------------------------------------------------------
    # H) Scenario Modification / Generation (if enabled)
    # --------------------------------------------------------------------------
    if modification_cfg.get("perform_modification", False):
        logger.info("[INFO] Scenario modification is ENABLED.")
        run_modification_workflow(modification_cfg["modify_config"])
    else:
        logger.info("[INFO] Skipping scenario modification.")

    # --------------------------------------------------------------------------
    # I) Global Validation (if enabled)
    # --------------------------------------------------------------------------
    if validation_cfg.get("perform_validation", False):
        logger.info("[INFO] Global Validation is ENABLED.")
        run_validation_process(validation_cfg["config"])
    else:
        logger.info("[INFO] Skipping global validation.")

    # --------------------------------------------------------------------------
    # J) Sensitivity Analysis (if enabled)
    # --------------------------------------------------------------------------
    if sens_cfg.get("perform_sensitivity", False):
        logger.info("[INFO] Sensitivity Analysis is ENABLED.")
        run_sensitivity_analysis(
            scenario_folder=sens_cfg["scenario_folder"],
            method=sens_cfg["method"],
            results_csv=sens_cfg.get("results_csv", ""),
            target_variable=sens_cfg.get("target_variable", ""),
            output_csv=sens_cfg.get("output_csv", "sensitivity_output.csv"),
            n_morris_trajectories=sens_cfg.get("n_morris_trajectories", 10),
            num_levels=sens_cfg.get("num_levels", 4),
            n_sobol_samples=sens_cfg.get("n_sobol_samples", 128)
        )
    else:
        logger.info("[INFO] Skipping sensitivity analysis.")

    # --------------------------------------------------------------------------
    # K) Surrogate Modeling (if enabled)
    # --------------------------------------------------------------------------
    if sur_cfg.get("perform_surrogate", False):
        logger.info("[INFO] Surrogate Modeling is ENABLED.")

        scenario_folder = sur_cfg["scenario_folder"]
        results_csv     = sur_cfg["results_csv"]
        target_var      = sur_cfg["target_variable"]
        model_out       = sur_cfg["model_out"]
        cols_out        = sur_cfg["cols_out"]
        test_size       = sur_cfg["test_size"]

        # 1) Load & pivot scenario params
        df_scen = sur_load_scenario_params(scenario_folder)
        pivot_df = pivot_scenario_params(df_scen)

        # 2) (Optional) filter top parameters if desired
        # pivot_df = filter_top_parameters(pivot_df, "morris_sensitivity.csv", top_n=5)

        # 3) Load & aggregate sim results
        df_sim = load_sim_results(results_csv)
        df_agg = aggregate_results(df_sim)

        # 4) Merge
        merged_df = merge_params_with_results(pivot_df, df_agg, target_var)

        # 5) Build & save surrogate
        rf_model, trained_cols = build_and_save_surrogate(
            df_data=merged_df,
            target_col=target_var,
            model_out_path=model_out,
            columns_out_path=cols_out,
            test_size=test_size,
            random_state=42
        )
        if rf_model:
            logger.info("[INFO] Surrogate model built & saved.")
        else:
            logger.warning("[WARN] Surrogate modeling failed or insufficient data.")
    else:
        logger.info("[INFO] Skipping surrogate modeling.")

    # --------------------------------------------------------------------------
    # L) Calibration (if enabled)
    # --------------------------------------------------------------------------
    if cal_cfg.get("perform_calibration", False):
        logger.info("[INFO] Calibration steps are ENABLED.")
        run_unified_calibration(cal_cfg)
    else:
        logger.info("[INFO] Skipping calibration steps.")

    logger.info("=== End of main.py ===")


###############################################################################
# 4) Script Entry
###############################################################################
if __name__ == "__main__":
    main()
# Out:
# 2025-02-03 13:32:28 [INFO] __main__: === Starting main.py ===
# 2025-02-03 13:32:28 [INFO] __main__: [INFO] IDF creation is ENABLED.
# 2025-02-03 13:32:28 [INFO] idf_creation: --- Creating IDF for building index 0, ogc_fid=4136730 ---
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core', 'Zone3_FrontPerimeter', 'Zone3_RightPerimeter', 'Zone3_RearPerimeter', 'Zone3_LeftPerimeter', 'Zone3_Core']
# [add_fenestration] Building: 4136730 => WWR=0.028, used Window1C
# [DEBUG lighting] bldg_id=4136730, type='Residential', matched overrides => [{'building_id': 4136730, 'param_name': 'lights_wm2', 'min_val': 18.0, 'max_val': 20.0}, {'building_type': 'Residential', 'param_name': 'tN', 'min_val': 10999, 'max_val': 11999}]
# [DHW] building_id=4136730, dhw_key=Detached House
#      occupant_count=1 daily_liters=45.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_0_UseFraction, MyDHW_0_Setpoint
#      WATERHEATER => MyDHW_0_WaterHeater, fuel=Electricity, eff=0.9
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136730.
# [VENT OVERRIDES] bldg=4136730, infiltration_base=100.36394267984579, year_factor=21.402501075522267, sys=A, f_ctrl=0.9223210738148823, fanP=0.0, hrv_eff=0.0, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136730, system=A, infiltration=3.827 m3/s, vent=0.035 m3/s, #zones=15
#    => Created infiltration for Zone1_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone1_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone2_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_FrontPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RightPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_RearPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_LeftPerimeter: 0.2551 m3/s, ventilation: 0.0023 m3/s
#    => Created infiltration for Zone3_Core: 0.2551 m3/s, ventilation: 0.0023 m3/s
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# 2025-02-03 13:32:30 [INFO] idf_creation: --- Creating IDF for building index 1, ogc_fid=4136732 ---
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_0.idf
# [update_construction_materials] => Created fallback top-level constructions (CEILING1C, etc.).
# [update_construction_materials] => Created sub-element-based constructions:
#    ground_floor => ground_floor_Construction
#    ground_floor_window => ground_floor_WindowConst
#    exterior_wall => exterior_wall_Construction
#    exterior_wall_window => exterior_wall_WindowConst
#    flat_roof => flat_roof_Construction
#    flat_roof_window => flat_roof_WindowConst
#    inter_floor => inter_floor_Construction
#    inter_floor_window => inter_floor_WindowConst
#    interior_wall => interior_wall_Construction
#    interior_wall_window => interior_wall_WindowConst
#    windows => windows_Construction
#    windows_window => windows_WindowConst
#    doors => doors_Construction
#    doors_window => doors_WindowConst
# [assign_constructions_to_surfaces] => Surfaces assigned via sub-element logic.
# ZoneList 'ALL_ZONES' created with zones: ['Zone1_FrontPerimeter', 'Zone1_RightPerimeter', 'Zone1_RearPerimeter', 'Zone1_LeftPerimeter', 'Zone1_Core', 'Zone2_FrontPerimeter', 'Zone2_RightPerimeter', 'Zone2_RearPerimeter', 'Zone2_LeftPerimeter', 'Zone2_Core']
# [add_fenestration] Building: 4136732 => WWR=0.300, used Window1C
# [DEBUG lighting] bldg_id=4136732, type='Non-Residential', matched overrides => []
# [DHW] building_id=4136732, dhw_key=Detached House
#      occupant_count=2 daily_liters=90.0
#      setpoint=59.5C, tank_volume=0.278 m³
#      schedules => MyDHW_1_UseFraction, MyDHW_1_Setpoint
#      WATERHEATER => MyDHW_1_WaterHeater, fuel=Electricity, eff=0.9
# 2025-02-03 13:32:31 [INFO] idf_creation: [create_idfs_for_all_buildings] => Running simulations ...
# 2025-02-03 13:32:31 [INFO] root: [simulate_all] Starting...
# 2025-02-03 13:32:31 [INFO] root: [simulate_all] Found 2 tasks. Using 4 workers.
# [add_HVAC_Ideal_to_all_zones] Completed HVAC setup for building 4136732.
# [VENT OVERRIDES] bldg=4136732, infiltration_base=0.6278853596915768, year_factor=0.9050021510445334, sys=D, f_ctrl=0.7723210738148822, fanP=0.0, hrv_eff=0.7736471214164012, infiltration_sched=AlwaysOnSched, vent_sched=VentSched_DayNight
# [VENTILATION] Building 4136732, system=D, infiltration=0.004 m3/s, vent=0.093 m3/s, #zones=10
#    => Created infiltration for Zone1_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone1_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_FrontPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RightPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_RearPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_LeftPerimeter: 0.0004 m3/s, ventilation: 0.0093 m3/s
#    => Created infiltration for Zone2_Core: 0.0004 m3/s, ventilation: 0.0093 m3/s
#       -> Zone1_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone1_Core IdealLoads has HRV = 0.77
#       -> Zone2_FrontPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RightPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_RearPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_LeftPerimeter IdealLoads has HRV = 0.77
#       -> Zone2_Core IdealLoads has HRV = 0.77
# [GROUND TEMPS] Created SITE:GROUNDTEMPERATURE:BUILDINGSURFACE with monthly values: {'January': 2.6394267984578836, 'February': 3.5375161328340003, 'March': 4.550058636738239, 'April': 7.558026845372057, 'May': 14.472942428328025, 'June': 16.176699487422912, 'July': 18.78435913540969, 'August': 17.673877665258832, 'September': 14.84384363937054, 'October': 9.059594438876141, 'November': 6.65591392441081, 'December': 4.0107105762067246}
# [create_idf_for_building] IDF saved at: output/output_IDFs\building_1.idf
# 2025-02-03 13:32:37 [INFO] root: [simulate_all] All simulations complete.
# 2025-02-03 13:32:37 [INFO] idf_creation: [create_idfs_for_all_buildings] => Post-processing results & writing logs ...
# [merge_all_results] Reading output/Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg2.csv, Building 2
# [merge_all_results] Reading output/Sim_Results\Scenarios\2020\simulation_bldg3.csv, Building 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 498
#     494 ###############################################################################
#     495 # 4) Script Entry
#     496 ###############################################################################
#     497 if __name__ == "__main__":
# --> 498     main()
#
# Cell In[1], line 330, in main()
#     327             df_buildings = pd.DataFrame()
#     329     # 2) Create IDFs
# --> 330     create_idfs_for_all_buildings(
#     331         df_buildings=df_buildings,
#     332         scenario=scenario,
#     333         calibration_stage=calibration_stage,
#     334         strategy=strategy,
#     335         random_seed=random_seed,
#     336         user_config_geom=geom_data.get("geometry", []),
#     337         user_config_lighting=user_config_lighting,
#     338         user_config_dhw=user_config_dhw,
#     339         res_data=updated_res_data,
#     340         nonres_data=updated_nonres_data,
#     341         user_config_hvac=user_config_hvac,
#     342         user_config_vent=user_config_vent,
#     343         user_config_epw=user_config_epw,   # if your simulation uses it
#     344         output_definitions=output_definitions,
#     345         run_simulations=run_simulations,
#     346         simulate_config=simulate_config,
#     347         post_process=post_process,
#     348         post_process_config=post_process_config
#     349     )
#     350 else:
#     351     logger.info("[INFO] Skipping IDF creation per user config.")
#
# File d:\Documents\E_Plus_2030_py\idf_creation.py:478, in create_idfs_for_all_buildings(df_buildings, scenario, calibration_stage, strategy, random_seed, user_config_geom, user_config_lighting, user_config_dhw, res_data, nonres_data, user_config_hvac, user_config_vent, user_config_epw, output_definitions, run_simulations, simulate_config, post_process, post_process_config)
#     475     aggregator = proc_item.get("aggregator", "mean")  # daily aggregator
#     476     output_csv = proc_item.get("output_csv", "output/results/merged_default.csv")
# --> 478     merge_all_results(
#     479         base_output_dir=base_output_dir,
#     480         output_csv=output_csv,
#     481         convert_to_daily=convert_daily,
#     482         daily_aggregator=aggregator,
#     483         convert_to_monthly=convert_monthly
#     484     )
#     486 # Write CSV logs for assigned parameters
#     487 _write_geometry_csv(assigned_geom_log)
#
# File d:\Documents\E_Plus_2030_py\postproc\merge_results.py:214, in merge_all_results(base_output_dir, output_csv, convert_to_daily, daily_aggregator, convert_to_monthly, monthly_aggregator, postproc_log)
#     210     else:
#     211         # More than 2 pieces => unknown
#     212         return pd.NaT
# --> 214 df["parsed_dt"] = df["Date/Time_corrected"].apply(parse_dt)
#     216 ###################################################
#     217 # 5) Process each column (other than date/time)
#     218 ###################################################
#     219 for col in df.columns:
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File d:\Documents\E_Plus_2030_py\postproc\merge_results.py:178, in merge_all_results.<locals>.parse_dt(x)
#     176 # Parse date part
#     177 try:
# --> 178     date_obj = datetime.strptime(date_part, "%m/%d")
#     179 except ValueError:
#     180     return pd.NaT
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\_strptime.py:322, in _strptime(data_string, format)
#     320 with _cache_lock:
#     321     locale_time = _TimeRE_cache.locale_time
# --> 322     if (_getlang() != locale_time.lang or
#     323         time.tzname != locale_time.tzname or
#     324         time.daylight != locale_time.daylight):
#     325         _TimeRE_cache = TimeRE()
#     326         _regex_cache.clear()
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\_strptime.py:28, in _getlang()
#      26 def _getlang():
#      27     # Figure out what the current language is set to.
# ---> 28     return locale.getlocale(locale.LC_TIME)
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\locale.py:593, in getlocale(category)
#     591 if category == LC_ALL and ';' in localename:
#     592     raise TypeError('category LC_ALL is not supported')
# --> 593 return _parse_localename(localename)
#
# File d:\New folder (2)\Anaconda\DDsaie\lib\locale.py:483, in _parse_localename(localename)
#     469 def _parse_localename(localename):
#     471     """ Parses the locale code for localename and returns the
#     472         result as tuple (language code, encoding).
#     473
#    (...)
#     481
#     482     """
# --> 483     code = normalize(localename)
#     484     if '@' in code:
#     485         # Deal with locale modifiers
#     486         code, modifier = code.split('@', 1)
#
# KeyboardInterrupt:
